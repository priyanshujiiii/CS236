# %% [markdown]
# # Domain Adversarial Networks (DAN / DANN)
#
# ## 1. Definition
#
# A **Domain Adversarial Network (DANN)** is a neural network designed to learn **domain-invariant features** so that a model trained on a **source domain** generalizes to a **target domain** without labels.
#
# Given:
#
# - Source data: $(x_s, y_s) \sim p_s(x, y)$
# - Target data: $x_t \sim p_t(x)$ (no labels)
# - Feature extractor: $F(x)$
# - Label predictor: $C(F(x))$
# - Domain discriminator: $D(F(x))$
#
# The idea is:
#
# - $C$ is trained to predict labels on the source domain.
# - $D$ is trained to distinguish whether features come from source or target.
# - $F$ is trained **adversarially** to fool $D$ so that source and target features become indistinguishable.
#
# Thus $F$ becomes **domain-invariant**.
#
# ---
#
# ## 2. Objective Function
#
# Two goals:
#
# 1. **Label classification loss** on source domain
#    $ \mathcal{L}_{cls} = \mathbb{E}_{(x_s,y_s)}\left[ \ell( C(F(x_s)),\, y_s ) \right] $
#
# 2. **Domain adversarial loss** using binary classification
#    $ \mathcal{L}_{dom} = \mathbb{E}_{x_s}[\log D(F(x_s))] + \mathbb{E}_{x_t}[\log (1 - D(F(x_t)))] $
#
# Final DANN objective:
#
# $ \min_{F,C} \max_D \; \mathcal{L}_{cls} - \lambda \mathcal{L}_{dom} $
#
# Here:
#
# - $D$ maximizes $\mathcal{L}_{dom}$
# - $F$ minimizes $\mathcal{L}_{cls}$ and **minimizes** $(-\mathcal{L}_{dom})$, i.e., it **fools $D$**
# - $\lambda$ controls adaptation strength
#
# ---
#
# ## 3. Derivation: Why Adversarial Training Leads to Domain Invariance
#
# ### Step 1: Domain classifier objective
#
# The discriminator tries to classify domain labels:
#
# - Domain label $d = 1$ for source
# - Domain label $d = 0$ for target
#
# Optimal discriminator is:
#
# $ D^\*(F(x)) = \frac{p_s(F(x))}{p_s(F(x)) + p_t(F(x))} $
#
# ---
#
# ### Step 2: Substitute $D^\*$ into adversarial loss
#
# Adversarial loss becomes the binary cross entropy:
#
# $ \mathcal{L}_{dom}(F) = -\log 4 + 2 \cdot \text{JS}(p_s(F(x)) \;\|\; p_t(F(x))) $
#
# Thus, minimizing the domain loss w.r.t. $F$ gives:
#
# $ F^\* = \arg\min \text{JS}(p_s(F(x)), p_t(F(x))) $
#
# This means the feature extractor learns:
#
# $ p_s(F(x)) \approx p_t(F(x)) $
#
# ⇒ **source and target feature distributions align**
#
# ---
#
# ### Step 3: Final objective
#
# Plug back into the joint objective:
#
# $ \min_{F,C} \max_D \left( \mathcal{L}_{cls} - \lambda \mathcal{L}_{dom} \right) $
#
# This yields a saddle point:
#
# - Minimization w.r.t. $F$ reduces classification loss
# - Minimization w.r.t. $F$ also forces domain feature alignment
# - Maximization w.r.t. $D$ improves domain discrimination
#
# ---
#
# ## 4. Gradient Reversal Layer (GRL)
#
# To implement adversarial training efficiently, DANN uses a **gradient reversal layer**:
#
# - Forward pass: identity
#   $ \text{GRL}(h) = h $
#
# - Backward pass: multiplies gradient by $- \lambda$
#   $ \frac{\partial \text{GRL}}{\partial h} = -\lambda I $
#
# This makes:
#
# - $D$ receive normal gradients
# - $F$ receive reversed gradients, forcing domain confusion
#
# ---
#
# ## 5. Summary
#
# - DANN learns **domain-invariant features** using adversarial training.
# - Objective:
#   $ \min_{F,C} \max_D \left( \mathcal{L}_{cls} - \lambda \mathcal{L}_{dom} \right) $
# - Domain alignment minimizes the Jensen–Shannon divergence between feature distributions.
# - Implemented using the Gradient Reversal Layer.
# - Widely used in **unsupervised domain adaptation**.

# %%
import torch
from torchvision import datasets
from torchvision import transforms
import os


def get_loader(args):
    if args.dset == 's2m':
        svhn_tr = transforms.Compose([transforms.Resize([32, 32]),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.5], [0.5])])
        s_train = datasets.SVHN(os.path.join(args.data_path, 'svhn'), split='train', download=True, transform=svhn_tr)
        s_test = datasets.SVHN(os.path.join(args.data_path, 'svhn'), split='test', download=True, transform=svhn_tr)

        mnist_tr = transforms.Compose([transforms.Resize([32, 32]),
                                       transforms.Grayscale(3),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.5], [0.5])])
        t_train = datasets.MNIST(os.path.join(args.data_path, 'mnist'), train=True, download=True, transform=mnist_tr)
        t_test = datasets.MNIST(os.path.join(args.data_path, 'mnist'), train=False, download=True, transform=mnist_tr)

    elif args.dset == 'u2m':
        tr = transforms.Compose([transforms.Resize([32, 32]),
                                 transforms.ToTensor(),
                                 transforms.Normalize([0.5], [0.5])])
        s_train = datasets.USPS(os.path.join(args.data_path, 'usps'), train=True, download=True, transform=tr)
        s_test = datasets.USPS(os.path.join(args.data_path, 'usps'), train=False, download=True, transform=tr)

        t_train = datasets.MNIST(os.path.join(args.data_path, 'mnist'), train=True, download=True, transform=tr)
        t_test = datasets.MNIST(os.path.join(args.data_path, 'mnist'), train=False, download=True, transform=tr)

    elif args.dset == 'm2u':
        tr = transforms.Compose([transforms.Resize([32, 32]),
                                 transforms.ToTensor(),
                                 transforms.Normalize([0.5], [0.5])])
        s_train = datasets.MNIST(os.path.join(args.data_path, 'mnist'), train=True, download=True, transform=tr)
        s_test = datasets.MNIST(os.path.join(args.data_path, 'mnist'), train=False, download=True, transform=tr)

        t_train = datasets.USPS(os.path.join(args.data_path, 'usps'), train=True, download=True, transform=tr)
        t_test = datasets.USPS(os.path.join(args.data_path, 'usps'), train=False, download=True, transform=tr)

    elif args.dset == 'm2mm':
        mnist_tr = transforms.Compose([transforms.Resize([32, 32]),
                                       transforms.Grayscale(3),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.5], [0.5])])

        s_train = datasets.MNIST(os.path.join(args.data_path, 'mnist'), train=True, download=True, transform=mnist_tr)
        s_test = datasets.MNIST(os.path.join(args.data_path, 'mnist'), train=False, download=True, transform=mnist_tr)

        mnistm_tr = transforms.Compose([transforms.Resize([32, 32]),
                                        transforms.ToTensor(),
                                        transforms.Normalize([0.5], [0.5])])

        t_train = datasets.ImageFolder(root=os.path.join(args.data_path, 'mnistm', 'trainset'), transform=mnistm_tr)
        t_test = datasets.ImageFolder(root=os.path.join(args.data_path, 'mnistm', 'testset'), transform=mnistm_tr)

    elif args.dset == 'sd2sv':
        tr = transforms.Compose([transforms.Resize([32, 32]),
                                 transforms.ToTensor(),
                                 transforms.Normalize([0.5], [0.5])])

        s_train = datasets.ImageFolder(root=os.path.join(args.data_path, 'sydigits', 'trainset'), transform=tr)
        s_test = datasets.ImageFolder(root=os.path.join(args.data_path, 'sydigits', 'trainset'), transform=tr)  # Does not have a testset

        t_train = datasets.SVHN(os.path.join(args.data_path, 'svhn'), split='train', download=True, transform=tr)
        t_test = datasets.SVHN(os.path.join(args.data_path, 'svhn'), split='test', download=True, transform=tr)

    elif args.dset == 'signs':
        tr = transforms.Compose([transforms.Resize([32, 32]),
                                 transforms.ToTensor(),
                                 transforms.Normalize([0.5], [0.5])])

        s_train = datasets.ImageFolder(root=os.path.join(args.data_path, 'sysigns', 'trainset'), transform=tr)
        s_test = datasets.ImageFolder(root=os.path.join(args.data_path, 'sysigns', 'trainset'), transform=tr)  # Does not have a testset

        t_train = datasets.ImageFolder(root=os.path.join(args.data_path, 'gtsrb', 'trainset'), transform=tr)
        t_test = datasets.ImageFolder(root=os.path.join(args.data_path, 'gtsrb', 'testset'), transform=tr)

    s_train_loader = torch.utils.data.DataLoader(dataset=s_train,
                                                 batch_size=args.batch_size,
                                                 shuffle=True,
                                                 num_workers=args.num_workers,
                                                 drop_last=True)

    s_test_loader = torch.utils.data.DataLoader(dataset=s_test,
                                                batch_size=args.batch_size * 2,
                                                shuffle=False,
                                                num_workers=args.num_workers,
                                                drop_last=False)

    t_train_loader = torch.utils.data.DataLoader(dataset=t_train,
                                                 batch_size=args.batch_size,
                                                 shuffle=True,
                                                 num_workers=args.num_workers,
                                                 drop_last=True)

    t_test_loader = torch.utils.data.DataLoader(dataset=t_test,
                                                batch_size=args.batch_size * 2,
                                                shuffle=False,
                                                num_workers=args.num_workers,
                                                drop_last=False)

    return s_train_loader, s_test_loader, t_train_loader, t_test_loader

# %%
import math
from torch.autograd import Function


class GradReverse(Function):
    @staticmethod
    def forward(ctx, x, lamda):
        ctx.lamda = lamda
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = (grad_output.neg() * ctx.lamda)
        return output, None


def adjust_alpha(i, epoch, min_len, nepochs):
    p = float(i + epoch * min_len) / nepochs / min_len
    o = -10
    alpha = 2. / (1. + math.exp(o * p)) - 1
    return alpha

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch



class encoder(nn.Module):
    def __init__(self, args):
        super(encoder, self).__init__()
        conv_dim = 32

        self.conv1 = nn.Conv2d(args.channels, conv_dim, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(conv_dim, conv_dim, kernel_size=3, padding=1)
        self.pool3 = nn.MaxPool2d(2, stride=2)

        self.conv4 = nn.Conv2d(conv_dim, conv_dim * 2, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(conv_dim * 2, conv_dim * 2, kernel_size=3, padding=1)
        self.pool6 = nn.MaxPool2d(2, stride=2)

        self.conv7 = nn.Conv2d(conv_dim * 2, conv_dim * 4, kernel_size=3, padding=1)
        self.conv8 = nn.Conv2d(conv_dim * 4, conv_dim * 4, kernel_size=3, padding=1)
        self.pool9 = nn.MaxPool2d(2, stride=2)

        self.flat_dim = 4 * 4 * conv_dim * 4
        self.fc1 = nn.Linear(self.flat_dim, 128)

        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = self.pool3(x)

        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = self.pool6(x)

        x = F.relu(self.conv7(x))
        x = F.relu(self.conv8(x))
        x = self.pool9(x)

        x = x.view(-1, self.flat_dim)
        x = F.relu(self.fc1(x))
        return x


class classifier(nn.Module):
    def __init__(self, args):
        super(classifier, self).__init__()
        self.fc1 = nn.Linear(128, args.num_classes)

        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)

    def forward(self, x):
        x = self.fc1(x)
        return x


class discriminator(nn.Module):
    def __init__(self, args):
        super(discriminator, self).__init__()
        self.args = args

        self.l1 = nn.Linear(128, 500)
        self.l2 = nn.Linear(500, 500)
        self.l3 = nn.Linear(500, 1)

        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0.0, 0.02)

    def forward(self, x, alpha=-1):
        if self.args.method.lower() == 'dann':
            x = GradReverse.apply(x, alpha)
        x = F.leaky_relu(self.l1(x), 0.2)
        x = F.leaky_relu(self.l2(x), 0.2)
        x = torch.sigmoid(self.l3(x))
        return x

# %%
import torch
import torch.nn as nn
import os
from torch import optim

from sklearn.metrics import confusion_matrix, accuracy_score


import copy
import torch.nn.functional as F
from torchsummary import summary

class Solver(object):
    def __init__(self, args):
        self.args = args

        self.s_train_loader, self.s_test_loader, self.t_train_loader, self.t_test_loader = get_loader(args)

        self.ce = nn.CrossEntropyLoss()
        self.bce = nn.BCELoss()

        self.best_acc = 0
        self.time_taken = None

        self.enc = encoder(self.args).cuda()
        self.clf = classifier(self.args).cuda()
        self.fd = discriminator(self.args).cuda()

        print('--------Network--------')
        print(self.enc)
        print(self.clf)

        print('--------Feature Disc--------')
        print(self.fd)

        self.fake_label = torch.FloatTensor(self.args.batch_size, 1).fill_(0).cuda()
        self.real_label = torch.FloatTensor(self.args.batch_size, 1).fill_(1).cuda()

        if not args.method == 'src':
            if os.path.exists(os.path.join(self.args.model_path, 'src_enc.pt')):
                print("Loading Source model...")
                self.enc.load_state_dict(torch.load(os.path.join(self.args.model_path, 'src_enc.pt')))
                self.clf.load_state_dict(torch.load(os.path.join(self.args.model_path, 'src_clf.pt')))
            else:
                print("Training Source model...")
                self.src()
                self.test()

    def test_dataset(self, db='t_test'):
        self.enc.eval()
        self.clf.eval()

        actual = []
        pred = []

        if db.lower() == 's_train':
            loader = self.s_train_loader
        elif db.lower() == 's_test':
            loader = self.s_test_loader
        elif db.lower() == 't_train':
            loader = self.t_train_loader
        else:
            loader = self.t_test_loader

        for data in loader:
            img, label = data

            img = img.cuda()

            with torch.no_grad():
                class_out = self.clf(self.enc(img))
            _, predicted = torch.max(class_out.data, 1)

            actual += label.tolist()
            pred += predicted.tolist()

        acc = accuracy_score(y_true=actual, y_pred=pred) * 100
        cm = confusion_matrix(y_true=actual, y_pred=pred, labels=range(self.args.num_classes))

        return acc, cm

    def test(self):
        s_train_acc, cm = self.test_dataset('s_train')
        print("Source Tr Acc: %.2f" % (s_train_acc))
        if self.args.cm:
            print(cm)

        s_test_acc, cm = self.test_dataset('s_test')
        print("Source Te Acc: %.2f" % (s_test_acc))
        if self.args.cm:
            print(cm)

        t_train_acc, cm = self.test_dataset('t_train')
        print("Target Tr Acc: %.2f" % (t_train_acc))
        if self.args.cm:
            print(cm)

        t_test_acc, cm = self.test_dataset('t_test')
        print("Target Te Acc: %.2f" % (t_test_acc))
        if self.args.cm:
            print(cm)

        return s_train_acc, s_test_acc, t_train_acc, t_test_acc

    def src(self):
        total_iters = 0
        self.best_acc = 0
        s_iter_per_epoch = len(iter(self.s_train_loader))
        self.args.src_test_epoch = max(self.args.src_epochs // 10, 1)

        self.optimizer = optim.Adam(list(self.enc.parameters()) + list(self.clf.parameters()), self.args.lr,
                                    betas=[0.5, 0.999], weight_decay=self.args.weight_decay)

        for epoch in range(self.args.src_epochs):

            self.clf.train()
            self.enc.train()

            for i, (source, s_labels) in enumerate(self.s_train_loader):
                total_iters += 1

                source, s_labels = source.cuda(), s_labels.cuda()

                s_logits = self.clf(self.enc(source))
                s_clf_loss = self.ce(s_logits, s_labels)
                loss = s_clf_loss

                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

                if i % 50 == 0 or i == (s_iter_per_epoch - 1):
                    print('Ep: %d/%d, iter: %d/%d, total_iters: %d, s_err: %.4f'
                          % (epoch + 1, self.args.src_epochs, i + 1, s_iter_per_epoch, total_iters, s_clf_loss))

            if (epoch + 1) % self.args.src_test_epoch == 0:
                s_test_acc, cm = self.test_dataset('s_test')
                print("Source test acc: %0.2f" % (s_test_acc))
                if self.args.cm:
                    print(cm)

                if s_test_acc > self.best_acc:
                    self.best_acc = s_test_acc
                    best_enc = copy.deepcopy(self.enc.state_dict())
                    best_clf = copy.deepcopy(self.clf.state_dict())

        torch.save(best_enc, os.path.join(self.args.model_path, 'src_enc.pt'))
        torch.save(best_clf, os.path.join(self.args.model_path, 'src_clf.pt'))

        self.enc.load_state_dict(best_enc)
        self.clf.load_state_dict(best_clf)

    def dann(self):

        s_iter_per_epoch = len(self.s_train_loader)
        t_iter_per_epoch = len(self.t_train_loader)
        min_len = min(s_iter_per_epoch, t_iter_per_epoch)
        total_iters = 0

        print("Source iters per epoch: %d" % (s_iter_per_epoch))
        print("Target iters per epoch: %d" % (t_iter_per_epoch))
        print("iters per epoch: %d" % (min(s_iter_per_epoch, t_iter_per_epoch)))

        self.optimizer = optim.Adam(list(self.enc.parameters()) + list(self.clf.parameters()) + list(self.fd.parameters()), self.args.lr,
                                      betas=[0.5, 0.999], weight_decay=self.args.weight_decay)

        for epoch in range(self.args.adapt_epochs):
            self.clf.train()
            self.enc.train()
            self.fd.train()

            for i, (source_data, target_data) in enumerate(zip(self.s_train_loader, self.t_train_loader)):
                total_iters += 1
                alpha = adjust_alpha(i, epoch, min_len, self.args.adapt_epochs)

                source, s_labels = source_data
                source, s_labels = source.cuda(), s_labels.cuda()

                target, t_labels = target_data
                target, t_labels = target.cuda(), t_labels.cuda()

                s_deep = self.enc(source)
                s_out = self.clf(s_deep)

                t_deep = self.enc(target)
                t_out = self.clf(t_deep)

                s_fd_out = self.fd(s_deep, alpha=alpha)
                t_fd_out = self.fd(t_deep, alpha=alpha)

                s_domain_err = self.bce(s_fd_out, self.real_label)
                t_domain_err = self.bce(t_fd_out, self.fake_label)
                disc_loss = s_domain_err + t_domain_err

                s_clf_loss = self.ce(s_out, s_labels)

                loss = s_clf_loss + disc_loss

                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

                if i % 50 == 0 or i == (min_len - 1):
                    print('Ep: %d/%d, iter: %d/%d, total_iters: %d, s_err: %.4f, d_err: %.4f, alpha: %.4f'
                          % (epoch + 1, self.args.adapt_epochs, i + 1, min_len, total_iters, s_clf_loss, disc_loss, alpha))

            if (epoch + 1) % self.args.adapt_test_epoch == 0:
                t_test_acc, cm = self.test_dataset('t_test')
                print("Target test acc: %0.2f" % (t_test_acc))
                if self.args.cm:
                    print(cm)

        torch.save(self.enc.state_dict(), os.path.join(self.args.model_path, 'dann_enc.pt'))
        torch.save(self.clf.state_dict(), os.path.join(self.args.model_path, 'dann_clf.pt'))
        torch.save(self.fd.state_dict(), os.path.join(self.args.model_path, 'dann_disc.pt'))

# %%
import os
import torch
import random
import numpy as np
import datetime


# ------------------------------
# ❗ Your Solver should be defined elsewhere or imported.
# from solver import Solver
# ------------------------------


class AttrDict(dict):
    """Make args.x attribute-style accessible"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__


def update_args(args):
    args.adapt_epochs = 200
    args.channels = 3
    args.num_classes = 10
    args.cm = True

    if args.dset == 's2m':
        args.source = 'svhn'
        args.target = 'mnist'

    elif args.dset == 'u2m':
        args.source = 'usps'
        args.target = 'mnist'
        args.channels = 1
        args.adapt_epochs = 1000

    elif args.dset == 'm2u':
        args.source = 'mnist'
        args.target = 'usps'
        args.channels = 1
        args.adapt_epochs = 1000

    elif args.dset == 'm2mm':
        args.source = 'mnist'
        args.target = 'mnistm'

    elif args.dset == 'sd2sv':
        args.source = 'sydigits'
        args.target = 'svhn'

    elif args.dset == 'signs':
        args.source = 'sysigns'
        args.target = 'gtsrb'
        args.num_classes = 43
        args.cm = False

    else:
        raise ValueError("Incorrect dataset combination")

    args.model_path = os.path.join(args.model_path, args.dset)
    args.adapt_test_epoch = args.adapt_epochs // 10

    return args


def print_args(args):
    for k, v in dict(sorted(args.items())).items():
        print(f"{k}: {v}")
    print()


def main(args):
    os.makedirs(args.model_path, exist_ok=True)

    solver = Solver(args)

    if args.method == 'src':
        solver.src()
    elif args.method == 'dann':
        solver.dann()

    solver.test()


# ---------------------------------------
# 🔥 COLAB CONFIG — Modify as needed
# ---------------------------------------

args = AttrDict({
    'p_thresh': 0.9,
    'method': 'src',       # or "dann"
    'src_epochs': 100,
    'batch_size': 128,
    'num_workers': 2,
    'lr': 1e-4,
    'weight_decay': 1e-5,
    'log_step': 50,

    'dset': 's2m',  # choose among: s2m, u2m, m2u, m2mm, sd2sv, signs
    'data_path': './data/',
    'model_path': './model',
    'seed': 100,
})

args = update_args(args)

# ---------------------------------------
# 🔧 SEED SETUP (Colab Safe)
# ---------------------------------------

manual_seed = args.seed
random.seed(manual_seed)
torch.manual_seed(manual_seed)
np.random.seed(manual_seed)
os.environ['PYTHONHASHSEED'] = str(manual_seed)

if torch.cuda.is_available():
    torch.cuda.manual_seed(manual_seed)
    torch.cuda.manual_seed_all(manual_seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# ---------------------------------------
# 📌 Print config in Colab
# ---------------------------------------

print("Training configuration:")
print_args(args)

start_time = datetime.datetime.now()
print("Started at:", start_time.strftime('%Y-%m-%d %H:%M:%S'))

# ---------------------------------------
# 🚀 RUN TRAINING
# ---------------------------------------

main(args)

end_time = datetime.datetime.now()
duration = end_time - start_time

print("Ended at:", end_time.strftime('%Y-%m-%d %H:%M:%S'))
print("Duration:", duration)
# Out:
# Training configuration:
# adapt_epochs: 200
# adapt_test_epoch: 20
# batch_size: 128
# channels: 3
# cm: True
# data_path: ./data/
# dset: s2m
# log_step: 50
# lr: 0.0001
# method: src
# model_path: ./model/s2m
# num_classes: 10
# num_workers: 2
# p_thresh: 0.9
# seed: 100
# source: svhn
# src_epochs: 100
# target: mnist
# weight_decay: 1e-05
#
# Started at: 2025-12-04 19:36:29
# 100%|██████████| 182M/182M [00:37<00:00, 4.83MB/s]
# 100%|██████████| 64.3M/64.3M [00:14<00:00, 4.33MB/s]
# 100%|██████████| 9.91M/9.91M [00:04<00:00, 2.07MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 131kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.24MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.10MB/s]
# --------Network--------
# encoder(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv8): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=2048, out_features=128, bias=True)
# )
# classifier(
#   (fc1): Linear(in_features=128, out_features=10, bias=True)
# )
# --------Feature Disc--------
# discriminator(
#   (l1): Linear(in_features=128, out_features=500, bias=True)
#   (l2): Linear(in_features=500, out_features=500, bias=True)
#   (l3): Linear(in_features=500, out_features=1, bias=True)
# )
# /tmp/ipython-input-2413062656.py:133: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   print('Ep: %d/%d, iter: %d/%d, total_iters: %d, s_err: %.4f'
# Ep: 1/100, iter: 1/572, total_iters: 1, s_err: 3.0055
# Ep: 1/100, iter: 51/572, total_iters: 51, s_err: 2.2779
# Ep: 1/100, iter: 101/572, total_iters: 101, s_err: 2.1377
# Ep: 1/100, iter: 151/572, total_iters: 151, s_err: 1.9433
# Ep: 1/100, iter: 201/572, total_iters: 201, s_err: 1.7359
# Ep: 1/100, iter: 251/572, total_iters: 251, s_err: 1.3909
# Ep: 1/100, iter: 301/572, total_iters: 301, s_err: 1.2097
# Ep: 1/100, iter: 351/572, total_iters: 351, s_err: 0.9503
# Ep: 1/100, iter: 401/572, total_iters: 401, s_err: 1.1261
# Ep: 1/100, iter: 451/572, total_iters: 451, s_err: 0.8767
# Ep: 1/100, iter: 501/572, total_iters: 501, s_err: 0.6626
# Ep: 1/100, iter: 551/572, total_iters: 551, s_err: 0.6652
# Ep: 1/100, iter: 572/572, total_iters: 572, s_err: 0.5190
# Ep: 2/100, iter: 1/572, total_iters: 573, s_err: 0.6120
# Ep: 2/100, iter: 51/572, total_iters: 623, s_err: 0.5747
# Ep: 2/100, iter: 101/572, total_iters: 673, s_err: 0.4228
# Ep: 2/100, iter: 151/572, total_iters: 723, s_err: 0.5365
# Ep: 2/100, iter: 201/572, total_iters: 773, s_err: 0.6887
# Ep: 2/100, iter: 251/572, total_iters: 823, s_err: 0.5706
# Ep: 2/100, iter: 301/572, total_iters: 873, s_err: 0.4256
# Ep: 2/100, iter: 351/572, total_iters: 923, s_err: 0.5469
# Ep: 2/100, iter: 401/572, total_iters: 973, s_err: 0.4998
# Ep: 2/100, iter: 451/572, total_iters: 1023, s_err: 0.5854
# Ep: 2/100, iter: 501/572, total_iters: 1073, s_err: 0.6913
# Ep: 2/100, iter: 551/572, total_iters: 1123, s_err: 0.4932
# Ep: 2/100, iter: 572/572, total_iters: 1144, s_err: 0.4537
# Ep: 3/100, iter: 1/572, total_iters: 1145, s_err: 0.2936
# Ep: 3/100, iter: 51/572, total_iters: 1195, s_err: 0.2923
# Ep: 3/100, iter: 101/572, total_iters: 1245, s_err: 0.3174
# Ep: 3/100, iter: 151/572, total_iters: 1295, s_err: 0.4936
# Ep: 3/100, iter: 201/572, total_iters: 1345, s_err: 0.3784
# Ep: 3/100, iter: 251/572, total_iters: 1395, s_err: 0.5267
# Ep: 3/100, iter: 301/572, total_iters: 1445, s_err: 0.4308
# Ep: 3/100, iter: 351/572, total_iters: 1495, s_err: 0.3963
# Ep: 3/100, iter: 401/572, total_iters: 1545, s_err: 0.3848
# Ep: 3/100, iter: 451/572, total_iters: 1595, s_err: 0.4912
# Ep: 3/100, iter: 501/572, total_iters: 1645, s_err: 0.4165
# Ep: 3/100, iter: 551/572, total_iters: 1695, s_err: 0.3454
# Ep: 3/100, iter: 572/572, total_iters: 1716, s_err: 0.4241
# Ep: 4/100, iter: 1/572, total_iters: 1717, s_err: 0.2803
# Ep: 4/100, iter: 51/572, total_iters: 1767, s_err: 0.3203
# Ep: 4/100, iter: 101/572, total_iters: 1817, s_err: 0.4184
# Ep: 4/100, iter: 151/572, total_iters: 1867, s_err: 0.3127
# Ep: 4/100, iter: 201/572, total_iters: 1917, s_err: 0.5346
# Ep: 4/100, iter: 251/572, total_iters: 1967, s_err: 0.3914
# Ep: 4/100, iter: 301/572, total_iters: 2017, s_err: 0.4330
# Ep: 4/100, iter: 351/572, total_iters: 2067, s_err: 0.3232
# Ep: 4/100, iter: 401/572, total_iters: 2117, s_err: 0.4478
# Ep: 4/100, iter: 451/572, total_iters: 2167, s_err: 0.3262
# Ep: 4/100, iter: 501/572, total_iters: 2217, s_err: 0.4824
# Ep: 4/100, iter: 551/572, total_iters: 2267, s_err: 0.3162
# Ep: 4/100, iter: 572/572, total_iters: 2288, s_err: 0.3700
# Ep: 5/100, iter: 1/572, total_iters: 2289, s_err: 0.3657
# Ep: 5/100, iter: 51/572, total_iters: 2339, s_err: 0.4195
# Ep: 5/100, iter: 101/572, total_iters: 2389, s_err: 0.3758
# Ep: 5/100, iter: 151/572, total_iters: 2439, s_err: 0.3190
# Ep: 5/100, iter: 201/572, total_iters: 2489, s_err: 0.3933
# Ep: 5/100, iter: 251/572, total_iters: 2539, s_err: 0.2289
# Ep: 5/100, iter: 301/572, total_iters: 2589, s_err: 0.2255
# Ep: 5/100, iter: 351/572, total_iters: 2639, s_err: 0.2495
# Ep: 5/100, iter: 401/572, total_iters: 2689, s_err: 0.2990
# Ep: 5/100, iter: 451/572, total_iters: 2739, s_err: 0.2801
# Ep: 5/100, iter: 501/572, total_iters: 2789, s_err: 0.2049
# Ep: 5/100, iter: 551/572, total_iters: 2839, s_err: 0.2849
# Ep: 5/100, iter: 572/572, total_iters: 2860, s_err: 0.2501
# Ep: 6/100, iter: 1/572, total_iters: 2861, s_err: 0.2646
# Ep: 6/100, iter: 51/572, total_iters: 2911, s_err: 0.3664
# Ep: 6/100, iter: 101/572, total_iters: 2961, s_err: 0.1561
# Ep: 6/100, iter: 151/572, total_iters: 3011, s_err: 0.1803
# Ep: 6/100, iter: 201/572, total_iters: 3061, s_err: 0.2674
# Ep: 6/100, iter: 251/572, total_iters: 3111, s_err: 0.2174
# Ep: 6/100, iter: 301/572, total_iters: 3161, s_err: 0.2517
# Ep: 6/100, iter: 351/572, total_iters: 3211, s_err: 0.3009
# Ep: 6/100, iter: 401/572, total_iters: 3261, s_err: 0.2346
# Ep: 6/100, iter: 451/572, total_iters: 3311, s_err: 0.2229
# Ep: 6/100, iter: 501/572, total_iters: 3361, s_err: 0.2878
# Ep: 6/100, iter: 551/572, total_iters: 3411, s_err: 0.2233
# Ep: 6/100, iter: 572/572, total_iters: 3432, s_err: 0.2367
# Ep: 7/100, iter: 1/572, total_iters: 3433, s_err: 0.2099
# Ep: 7/100, iter: 51/572, total_iters: 3483, s_err: 0.2992
# Ep: 7/100, iter: 101/572, total_iters: 3533, s_err: 0.2620
# Ep: 7/100, iter: 151/572, total_iters: 3583, s_err: 0.2157
# Ep: 7/100, iter: 201/572, total_iters: 3633, s_err: 0.1779
# Ep: 7/100, iter: 251/572, total_iters: 3683, s_err: 0.2670
# Ep: 7/100, iter: 301/572, total_iters: 3733, s_err: 0.3054
# Ep: 7/100, iter: 351/572, total_iters: 3783, s_err: 0.2157
# Ep: 7/100, iter: 401/572, total_iters: 3833, s_err: 0.2119
# Ep: 7/100, iter: 451/572, total_iters: 3883, s_err: 0.3237
# Ep: 7/100, iter: 501/572, total_iters: 3933, s_err: 0.3543
# Ep: 7/100, iter: 551/572, total_iters: 3983, s_err: 0.3717
# Ep: 7/100, iter: 572/572, total_iters: 4004, s_err: 0.2078
# Ep: 8/100, iter: 1/572, total_iters: 4005, s_err: 0.2444
# Ep: 8/100, iter: 51/572, total_iters: 4055, s_err: 0.2254
# Ep: 8/100, iter: 101/572, total_iters: 4105, s_err: 0.1869
# Ep: 8/100, iter: 151/572, total_iters: 4155, s_err: 0.2201
# Ep: 8/100, iter: 201/572, total_iters: 4205, s_err: 0.2743
# Ep: 8/100, iter: 251/572, total_iters: 4255, s_err: 0.2243
# Ep: 8/100, iter: 301/572, total_iters: 4305, s_err: 0.1075
# Ep: 8/100, iter: 351/572, total_iters: 4355, s_err: 0.2164
# Ep: 8/100, iter: 401/572, total_iters: 4405, s_err: 0.2080
# Ep: 8/100, iter: 451/572, total_iters: 4455, s_err: 0.1365
# Ep: 8/100, iter: 501/572, total_iters: 4505, s_err: 0.2150
# Ep: 8/100, iter: 551/572, total_iters: 4555, s_err: 0.2100
# Ep: 8/100, iter: 572/572, total_iters: 4576, s_err: 0.2186
# Ep: 9/100, iter: 1/572, total_iters: 4577, s_err: 0.2118
# Ep: 9/100, iter: 51/572, total_iters: 4627, s_err: 0.2682
# Ep: 9/100, iter: 101/572, total_iters: 4677, s_err: 0.1890
# Ep: 9/100, iter: 151/572, total_iters: 4727, s_err: 0.1937
# Ep: 9/100, iter: 201/572, total_iters: 4777, s_err: 0.1260
# Ep: 9/100, iter: 251/572, total_iters: 4827, s_err: 0.2134
# Ep: 9/100, iter: 301/572, total_iters: 4877, s_err: 0.2651
# Ep: 9/100, iter: 351/572, total_iters: 4927, s_err: 0.3657
# Ep: 9/100, iter: 401/572, total_iters: 4977, s_err: 0.0562
# Ep: 9/100, iter: 451/572, total_iters: 5027, s_err: 0.2498
# Ep: 9/100, iter: 501/572, total_iters: 5077, s_err: 0.1323
# Ep: 9/100, iter: 551/572, total_iters: 5127, s_err: 0.1644
# Ep: 9/100, iter: 572/572, total_iters: 5148, s_err: 0.1355
# Ep: 10/100, iter: 1/572, total_iters: 5149, s_err: 0.1597
# Ep: 10/100, iter: 51/572, total_iters: 5199, s_err: 0.0921
# Ep: 10/100, iter: 101/572, total_iters: 5249, s_err: 0.1912
# Ep: 10/100, iter: 151/572, total_iters: 5299, s_err: 0.2232
# Ep: 10/100, iter: 201/572, total_iters: 5349, s_err: 0.1578
# Ep: 10/100, iter: 251/572, total_iters: 5399, s_err: 0.2289
# Ep: 10/100, iter: 301/572, total_iters: 5449, s_err: 0.1393
# Ep: 10/100, iter: 351/572, total_iters: 5499, s_err: 0.1953
# Ep: 10/100, iter: 401/572, total_iters: 5549, s_err: 0.2329
# Ep: 10/100, iter: 451/572, total_iters: 5599, s_err: 0.2005
# Ep: 10/100, iter: 501/572, total_iters: 5649, s_err: 0.3658
# Ep: 10/100, iter: 551/572, total_iters: 5699, s_err: 0.0730
# Ep: 10/100, iter: 572/572, total_iters: 5720, s_err: 0.0883
# Source test acc: 88.71
# [[1561   33    9   11    9    3   44   10   18   46]
#  [  42 4799   32   25   82   10   13   63   21   12]
#  [  16   68 3710   73   52   19   24   67   57   63]
#  [  11   70   38 2322   25   66   35   17  105  193]
#  [  25   69   22   21 2305    3   23   10   19   26]
#  [  12   24   10   77   28 2026  119    8   36   44]
#  [  28   29    8   29   33   29 1742    9   57   13]
#  [   8  100   26   24    7    5    7 1816    4   22]
#  [  16   21   10   31   12   19   88    3 1395   65]
#  [  39   20   36   16    6   13   15   10   22 1418]]
# Ep: 11/100, iter: 1/572, total_iters: 5721, s_err: 0.1796
# Ep: 11/100, iter: 51/572, total_iters: 5771, s_err: 0.1201
# Ep: 11/100, iter: 101/572, total_iters: 5821, s_err: 0.0924
# Ep: 11/100, iter: 151/572, total_iters: 5871, s_err: 0.1709
# Ep: 11/100, iter: 201/572, total_iters: 5921, s_err: 0.2316
# Ep: 11/100, iter: 251/572, total_iters: 5971, s_err: 0.1681
# Ep: 11/100, iter: 301/572, total_iters: 6021, s_err: 0.2654
# Ep: 11/100, iter: 351/572, total_iters: 6071, s_err: 0.1531
# Ep: 11/100, iter: 401/572, total_iters: 6121, s_err: 0.1725
# Ep: 11/100, iter: 451/572, total_iters: 6171, s_err: 0.1396
# Ep: 11/100, iter: 501/572, total_iters: 6221, s_err: 0.1573
# Ep: 11/100, iter: 551/572, total_iters: 6271, s_err: 0.0858
# Ep: 11/100, iter: 572/572, total_iters: 6292, s_err: 0.1594
# Ep: 12/100, iter: 1/572, total_iters: 6293, s_err: 0.1641
# Ep: 12/100, iter: 51/572, total_iters: 6343, s_err: 0.0925
# Ep: 12/100, iter: 101/572, total_iters: 6393, s_err: 0.1782
# Ep: 12/100, iter: 151/572, total_iters: 6443, s_err: 0.0576
# Ep: 12/100, iter: 201/572, total_iters: 6493, s_err: 0.1359
# Ep: 12/100, iter: 251/572, total_iters: 6543, s_err: 0.2605
# Ep: 12/100, iter: 301/572, total_iters: 6593, s_err: 0.1308
# Ep: 12/100, iter: 351/572, total_iters: 6643, s_err: 0.1512
# Ep: 12/100, iter: 401/572, total_iters: 6693, s_err: 0.1944
# Ep: 12/100, iter: 451/572, total_iters: 6743, s_err: 0.2209
# Ep: 12/100, iter: 501/572, total_iters: 6793, s_err: 0.0974
# Ep: 12/100, iter: 551/572, total_iters: 6843, s_err: 0.1649
# Ep: 12/100, iter: 572/572, total_iters: 6864, s_err: 0.1433
# Ep: 13/100, iter: 1/572, total_iters: 6865, s_err: 0.2190
# Ep: 13/100, iter: 51/572, total_iters: 6915, s_err: 0.0927
# Ep: 13/100, iter: 101/572, total_iters: 6965, s_err: 0.1029
# Ep: 13/100, iter: 151/572, total_iters: 7015, s_err: 0.2305
# Ep: 13/100, iter: 201/572, total_iters: 7065, s_err: 0.1857
# Ep: 13/100, iter: 251/572, total_iters: 7115, s_err: 0.0574
# Ep: 13/100, iter: 301/572, total_iters: 7165, s_err: 0.1354
# Ep: 13/100, iter: 351/572, total_iters: 7215, s_err: 0.1974
# Ep: 13/100, iter: 401/572, total_iters: 7265, s_err: 0.0895
# Ep: 13/100, iter: 451/572, total_iters: 7315, s_err: 0.0834
# Ep: 13/100, iter: 501/572, total_iters: 7365, s_err: 0.1576
# Ep: 13/100, iter: 551/572, total_iters: 7415, s_err: 0.0916
# Ep: 13/100, iter: 572/572, total_iters: 7436, s_err: 0.2421
# Ep: 14/100, iter: 1/572, total_iters: 7437, s_err: 0.0846
# Ep: 14/100, iter: 51/572, total_iters: 7487, s_err: 0.0763
# Ep: 14/100, iter: 101/572, total_iters: 7537, s_err: 0.0551
# Ep: 14/100, iter: 151/572, total_iters: 7587, s_err: 0.0878
# Ep: 14/100, iter: 201/572, total_iters: 7637, s_err: 0.2529
# Ep: 14/100, iter: 251/572, total_iters: 7687, s_err: 0.1116
# Ep: 14/100, iter: 301/572, total_iters: 7737, s_err: 0.1434
# Ep: 14/100, iter: 351/572, total_iters: 7787, s_err: 0.1228
# Ep: 14/100, iter: 401/572, total_iters: 7837, s_err: 0.1477
# Ep: 14/100, iter: 451/572, total_iters: 7887, s_err: 0.0623
# Ep: 14/100, iter: 501/572, total_iters: 7937, s_err: 0.0524
# Ep: 14/100, iter: 551/572, total_iters: 7987, s_err: 0.0851
# Ep: 14/100, iter: 572/572, total_iters: 8008, s_err: 0.1124
# Ep: 15/100, iter: 1/572, total_iters: 8009, s_err: 0.1022
# Ep: 15/100, iter: 51/572, total_iters: 8059, s_err: 0.0885
# Ep: 15/100, iter: 101/572, total_iters: 8109, s_err: 0.1090
# Ep: 15/100, iter: 151/572, total_iters: 8159, s_err: 0.0678
# Ep: 15/100, iter: 201/572, total_iters: 8209, s_err: 0.0755
# Ep: 15/100, iter: 251/572, total_iters: 8259, s_err: 0.0952
# Ep: 15/100, iter: 301/572, total_iters: 8309, s_err: 0.0828
# Ep: 15/100, iter: 351/572, total_iters: 8359, s_err: 0.0740
# Ep: 15/100, iter: 401/572, total_iters: 8409, s_err: 0.0921
# Ep: 15/100, iter: 451/572, total_iters: 8459, s_err: 0.1241
# Ep: 15/100, iter: 501/572, total_iters: 8509, s_err: 0.1238
# Ep: 15/100, iter: 551/572, total_iters: 8559, s_err: 0.0880
# Ep: 15/100, iter: 572/572, total_iters: 8580, s_err: 0.0798
# Ep: 16/100, iter: 1/572, total_iters: 8581, s_err: 0.1507
# Ep: 16/100, iter: 51/572, total_iters: 8631, s_err: 0.1142
# Ep: 16/100, iter: 101/572, total_iters: 8681, s_err: 0.0851
# Ep: 16/100, iter: 151/572, total_iters: 8731, s_err: 0.0554
# Ep: 16/100, iter: 201/572, total_iters: 8781, s_err: 0.0808
# Ep: 16/100, iter: 251/572, total_iters: 8831, s_err: 0.0919
# Ep: 16/100, iter: 301/572, total_iters: 8881, s_err: 0.0673
# Ep: 16/100, iter: 351/572, total_iters: 8931, s_err: 0.1813
# Ep: 16/100, iter: 401/572, total_iters: 8981, s_err: 0.1050
# Ep: 16/100, iter: 451/572, total_iters: 9031, s_err: 0.0414
# Ep: 16/100, iter: 501/572, total_iters: 9081, s_err: 0.0707
# Ep: 16/100, iter: 551/572, total_iters: 9131, s_err: 0.1425
# Ep: 16/100, iter: 572/572, total_iters: 9152, s_err: 0.0545
# Ep: 17/100, iter: 1/572, total_iters: 9153, s_err: 0.0493
# Ep: 17/100, iter: 51/572, total_iters: 9203, s_err: 0.0279
# Ep: 17/100, iter: 101/572, total_iters: 9253, s_err: 0.0621
# Ep: 17/100, iter: 151/572, total_iters: 9303, s_err: 0.0226
# Ep: 17/100, iter: 201/572, total_iters: 9353, s_err: 0.0449
# Ep: 17/100, iter: 251/572, total_iters: 9403, s_err: 0.0615
# Ep: 17/100, iter: 301/572, total_iters: 9453, s_err: 0.0460
# Ep: 17/100, iter: 351/572, total_iters: 9503, s_err: 0.0307
# Ep: 17/100, iter: 401/572, total_iters: 9553, s_err: 0.0384
# Ep: 17/100, iter: 451/572, total_iters: 9603, s_err: 0.1732
# Ep: 17/100, iter: 501/572, total_iters: 9653, s_err: 0.1145
# Ep: 17/100, iter: 551/572, total_iters: 9703, s_err: 0.0227
# Ep: 17/100, iter: 572/572, total_iters: 9724, s_err: 0.0642
# Ep: 18/100, iter: 1/572, total_iters: 9725, s_err: 0.0555
# Ep: 18/100, iter: 51/572, total_iters: 9775, s_err: 0.0190
# Ep: 18/100, iter: 101/572, total_iters: 9825, s_err: 0.0221
# Ep: 18/100, iter: 151/572, total_iters: 9875, s_err: 0.0345
# Ep: 18/100, iter: 201/572, total_iters: 9925, s_err: 0.0364
# Ep: 18/100, iter: 251/572, total_iters: 9975, s_err: 0.0470
# Ep: 18/100, iter: 301/572, total_iters: 10025, s_err: 0.0951
# Ep: 18/100, iter: 351/572, total_iters: 10075, s_err: 0.0828
# Ep: 18/100, iter: 401/572, total_iters: 10125, s_err: 0.0342
# Ep: 18/100, iter: 451/572, total_iters: 10175, s_err: 0.0240
# Ep: 18/100, iter: 501/572, total_iters: 10225, s_err: 0.1167
# Ep: 18/100, iter: 551/572, total_iters: 10275, s_err: 0.0393
# Ep: 18/100, iter: 572/572, total_iters: 10296, s_err: 0.0937
# Ep: 19/100, iter: 1/572, total_iters: 10297, s_err: 0.0886
# Ep: 19/100, iter: 51/572, total_iters: 10347, s_err: 0.0273
# Ep: 19/100, iter: 101/572, total_iters: 10397, s_err: 0.0418
# Ep: 19/100, iter: 151/572, total_iters: 10447, s_err: 0.0191
# Ep: 19/100, iter: 201/572, total_iters: 10497, s_err: 0.0323
# Ep: 19/100, iter: 251/572, total_iters: 10547, s_err: 0.0380
# Ep: 19/100, iter: 301/572, total_iters: 10597, s_err: 0.0253
# Ep: 19/100, iter: 351/572, total_iters: 10647, s_err: 0.0325
# Ep: 19/100, iter: 401/572, total_iters: 10697, s_err: 0.0617
# Ep: 19/100, iter: 451/572, total_iters: 10747, s_err: 0.0561
# Ep: 19/100, iter: 501/572, total_iters: 10797, s_err: 0.0402
# Ep: 19/100, iter: 551/572, total_iters: 10847, s_err: 0.0433
# Ep: 19/100, iter: 572/572, total_iters: 10868, s_err: 0.0486
# Ep: 20/100, iter: 1/572, total_iters: 10869, s_err: 0.0326
# Ep: 20/100, iter: 51/572, total_iters: 10919, s_err: 0.0194
# Ep: 20/100, iter: 101/572, total_iters: 10969, s_err: 0.0104
# Ep: 20/100, iter: 151/572, total_iters: 11019, s_err: 0.0130
# Ep: 20/100, iter: 201/572, total_iters: 11069, s_err: 0.0081
# Ep: 20/100, iter: 251/572, total_iters: 11119, s_err: 0.0179
# Ep: 20/100, iter: 301/572, total_iters: 11169, s_err: 0.0230
# Ep: 20/100, iter: 351/572, total_iters: 11219, s_err: 0.0588
# Ep: 20/100, iter: 401/572, total_iters: 11269, s_err: 0.0637
# Ep: 20/100, iter: 451/572, total_iters: 11319, s_err: 0.0581
# Ep: 20/100, iter: 501/572, total_iters: 11369, s_err: 0.0325
# Ep: 20/100, iter: 551/572, total_iters: 11419, s_err: 0.0331
# Ep: 20/100, iter: 572/572, total_iters: 11440, s_err: 0.0265
# Source test acc: 87.77
# [[1543   11   28   14   10    4   74    9    6   45]
#  [ 115 4475  123   43  133   22   46  116    6   20]
#  [  13   18 3907   47   34   12   28   58    7   25]
#  [   9   27   85 2354   30   69   48   17   26  217]
#  [  22   34   55   17 2310    6   36   13    6   24]
#  [   9    8   33   82   17 2015  147   13   11   49]
#  [  24   13   16   17   14   26 1822   14   13   18]
#  [   9   33   64   27   12    5   15 1828    2   24]
#  [  30    7   32   47   17   20  219    6 1190   92]
#  [  31   12   71   12    8   15   23   10    8 1405]]
# Ep: 21/100, iter: 1/572, total_iters: 11441, s_err: 0.0512
# Ep: 21/100, iter: 51/572, total_iters: 11491, s_err: 0.0126
# Ep: 21/100, iter: 101/572, total_iters: 11541, s_err: 0.0109
# Ep: 21/100, iter: 151/572, total_iters: 11591, s_err: 0.0459
# Ep: 21/100, iter: 201/572, total_iters: 11641, s_err: 0.0445
# Ep: 21/100, iter: 251/572, total_iters: 11691, s_err: 0.0110
# Ep: 21/100, iter: 301/572, total_iters: 11741, s_err: 0.0098
# Ep: 21/100, iter: 351/572, total_iters: 11791, s_err: 0.0330
# Ep: 21/100, iter: 401/572, total_iters: 11841, s_err: 0.0354
# Ep: 21/100, iter: 451/572, total_iters: 11891, s_err: 0.0191
# Ep: 21/100, iter: 501/572, total_iters: 11941, s_err: 0.0214
# Ep: 21/100, iter: 551/572, total_iters: 11991, s_err: 0.0500
# Ep: 21/100, iter: 572/572, total_iters: 12012, s_err: 0.0427
# Ep: 22/100, iter: 1/572, total_iters: 12013, s_err: 0.0259
# Ep: 22/100, iter: 51/572, total_iters: 12063, s_err: 0.0064
# Ep: 22/100, iter: 101/572, total_iters: 12113, s_err: 0.0609
# Ep: 22/100, iter: 151/572, total_iters: 12163, s_err: 0.0181
# Ep: 22/100, iter: 201/572, total_iters: 12213, s_err: 0.0206
# Ep: 22/100, iter: 251/572, total_iters: 12263, s_err: 0.0274
# Ep: 22/100, iter: 301/572, total_iters: 12313, s_err: 0.0317
# Ep: 22/100, iter: 351/572, total_iters: 12363, s_err: 0.0737
# Ep: 22/100, iter: 401/572, total_iters: 12413, s_err: 0.0275
# Ep: 22/100, iter: 451/572, total_iters: 12463, s_err: 0.0194
# Ep: 22/100, iter: 501/572, total_iters: 12513, s_err: 0.0451
# Ep: 22/100, iter: 551/572, total_iters: 12563, s_err: 0.0449
# Ep: 22/100, iter: 572/572, total_iters: 12584, s_err: 0.0342
# Ep: 23/100, iter: 1/572, total_iters: 12585, s_err: 0.0121
# Ep: 23/100, iter: 51/572, total_iters: 12635, s_err: 0.0131
# Ep: 23/100, iter: 101/572, total_iters: 12685, s_err: 0.0047
# Ep: 23/100, iter: 151/572, total_iters: 12735, s_err: 0.0385
# Ep: 23/100, iter: 201/572, total_iters: 12785, s_err: 0.0502
# Ep: 23/100, iter: 251/572, total_iters: 12835, s_err: 0.0106
# Ep: 23/100, iter: 301/572, total_iters: 12885, s_err: 0.0810
# Ep: 23/100, iter: 351/572, total_iters: 12935, s_err: 0.0444
# Ep: 23/100, iter: 401/572, total_iters: 12985, s_err: 0.0505
# Ep: 23/100, iter: 451/572, total_iters: 13035, s_err: 0.0158
# Ep: 23/100, iter: 501/572, total_iters: 13085, s_err: 0.0261
# Ep: 23/100, iter: 551/572, total_iters: 13135, s_err: 0.0086
# Ep: 23/100, iter: 572/572, total_iters: 13156, s_err: 0.0740
# Ep: 24/100, iter: 1/572, total_iters: 13157, s_err: 0.0176
# Ep: 24/100, iter: 51/572, total_iters: 13207, s_err: 0.0188
# Ep: 24/100, iter: 101/572, total_iters: 13257, s_err: 0.0438
# Ep: 24/100, iter: 151/572, total_iters: 13307, s_err: 0.0206
# Ep: 24/100, iter: 201/572, total_iters: 13357, s_err: 0.0214
# Ep: 24/100, iter: 251/572, total_iters: 13407, s_err: 0.0418
# Ep: 24/100, iter: 301/572, total_iters: 13457, s_err: 0.0127
# Ep: 24/100, iter: 351/572, total_iters: 13507, s_err: 0.0241
# Ep: 24/100, iter: 401/572, total_iters: 13557, s_err: 0.0138
# Ep: 24/100, iter: 451/572, total_iters: 13607, s_err: 0.0388
# Ep: 24/100, iter: 501/572, total_iters: 13657, s_err: 0.0211
# Ep: 24/100, iter: 551/572, total_iters: 13707, s_err: 0.0451
# Ep: 24/100, iter: 572/572, total_iters: 13728, s_err: 0.0957
# Ep: 25/100, iter: 1/572, total_iters: 13729, s_err: 0.0204
# Ep: 25/100, iter: 51/572, total_iters: 13779, s_err: 0.0036
# Ep: 25/100, iter: 101/572, total_iters: 13829, s_err: 0.0216
# Ep: 25/100, iter: 151/572, total_iters: 13879, s_err: 0.0094
# Ep: 25/100, iter: 201/572, total_iters: 13929, s_err: 0.0154
# Ep: 25/100, iter: 251/572, total_iters: 13979, s_err: 0.0048
# Ep: 25/100, iter: 301/572, total_iters: 14029, s_err: 0.0487
# Ep: 25/100, iter: 351/572, total_iters: 14079, s_err: 0.0605
# Ep: 25/100, iter: 401/572, total_iters: 14129, s_err: 0.0165
# Ep: 25/100, iter: 451/572, total_iters: 14179, s_err: 0.0562
# Ep: 25/100, iter: 501/572, total_iters: 14229, s_err: 0.0617
# Ep: 25/100, iter: 551/572, total_iters: 14279, s_err: 0.0591
# Ep: 25/100, iter: 572/572, total_iters: 14300, s_err: 0.0607
# Ep: 26/100, iter: 1/572, total_iters: 14301, s_err: 0.0339
# Ep: 26/100, iter: 51/572, total_iters: 14351, s_err: 0.0032
# Ep: 26/100, iter: 101/572, total_iters: 14401, s_err: 0.0180
# Ep: 26/100, iter: 151/572, total_iters: 14451, s_err: 0.0123
# Ep: 26/100, iter: 201/572, total_iters: 14501, s_err: 0.0496
# Ep: 26/100, iter: 251/572, total_iters: 14551, s_err: 0.0327
# Ep: 26/100, iter: 301/572, total_iters: 14601, s_err: 0.0198
# Ep: 26/100, iter: 351/572, total_iters: 14651, s_err: 0.0864
# Ep: 26/100, iter: 401/572, total_iters: 14701, s_err: 0.0388
# Ep: 26/100, iter: 451/572, total_iters: 14751, s_err: 0.0212
# Ep: 26/100, iter: 501/572, total_iters: 14801, s_err: 0.0635
# Ep: 26/100, iter: 551/572, total_iters: 14851, s_err: 0.0354
# Ep: 26/100, iter: 572/572, total_iters: 14872, s_err: 0.0135
# Ep: 27/100, iter: 1/572, total_iters: 14873, s_err: 0.0354
# Ep: 27/100, iter: 51/572, total_iters: 14923, s_err: 0.0307
# Ep: 27/100, iter: 101/572, total_iters: 14973, s_err: 0.0027
# Ep: 27/100, iter: 151/572, total_iters: 15023, s_err: 0.0253
# Ep: 27/100, iter: 201/572, total_iters: 15073, s_err: 0.0354
# Ep: 27/100, iter: 251/572, total_iters: 15123, s_err: 0.0146
# Ep: 27/100, iter: 301/572, total_iters: 15173, s_err: 0.0255
# Ep: 27/100, iter: 351/572, total_iters: 15223, s_err: 0.0081
# Ep: 27/100, iter: 401/572, total_iters: 15273, s_err: 0.0021
# Ep: 27/100, iter: 451/572, total_iters: 15323, s_err: 0.0051
# Ep: 27/100, iter: 501/572, total_iters: 15373, s_err: 0.0481
# Ep: 27/100, iter: 551/572, total_iters: 15423, s_err: 0.0201
# Ep: 27/100, iter: 572/572, total_iters: 15444, s_err: 0.0038
# Ep: 28/100, iter: 1/572, total_iters: 15445, s_err: 0.0086
# Ep: 28/100, iter: 51/572, total_iters: 15495, s_err: 0.0178
# Ep: 28/100, iter: 101/572, total_iters: 15545, s_err: 0.0090
# Ep: 28/100, iter: 151/572, total_iters: 15595, s_err: 0.0162
# Ep: 28/100, iter: 201/572, total_iters: 15645, s_err: 0.0707
# Ep: 28/100, iter: 251/572, total_iters: 15695, s_err: 0.0111
# Ep: 28/100, iter: 301/572, total_iters: 15745, s_err: 0.0294
# Ep: 28/100, iter: 351/572, total_iters: 15795, s_err: 0.0114
# Ep: 28/100, iter: 401/572, total_iters: 15845, s_err: 0.0064
# Ep: 28/100, iter: 451/572, total_iters: 15895, s_err: 0.0400
# Ep: 28/100, iter: 501/572, total_iters: 15945, s_err: 0.0270
# Ep: 28/100, iter: 551/572, total_iters: 15995, s_err: 0.0256
# Ep: 28/100, iter: 572/572, total_iters: 16016, s_err: 0.0480
# Ep: 29/100, iter: 1/572, total_iters: 16017, s_err: 0.0439
# Ep: 29/100, iter: 51/572, total_iters: 16067, s_err: 0.0009
# Ep: 29/100, iter: 101/572, total_iters: 16117, s_err: 0.0012
# Ep: 29/100, iter: 151/572, total_iters: 16167, s_err: 0.0046
# Ep: 29/100, iter: 201/572, total_iters: 16217, s_err: 0.0065
# Ep: 29/100, iter: 251/572, total_iters: 16267, s_err: 0.0187
# Ep: 29/100, iter: 301/572, total_iters: 16317, s_err: 0.0116
# Ep: 29/100, iter: 351/572, total_iters: 16367, s_err: 0.0008
# Ep: 29/100, iter: 401/572, total_iters: 16417, s_err: 0.0601
# Ep: 29/100, iter: 451/572, total_iters: 16467, s_err: 0.0132
# Ep: 29/100, iter: 501/572, total_iters: 16517, s_err: 0.0056
# Ep: 29/100, iter: 551/572, total_iters: 16567, s_err: 0.0146
# Ep: 29/100, iter: 572/572, total_iters: 16588, s_err: 0.0072
# Ep: 30/100, iter: 1/572, total_iters: 16589, s_err: 0.0081
# Ep: 30/100, iter: 51/572, total_iters: 16639, s_err: 0.0086
# Ep: 30/100, iter: 101/572, total_iters: 16689, s_err: 0.0160
# Ep: 30/100, iter: 151/572, total_iters: 16739, s_err: 0.0041
# Ep: 30/100, iter: 201/572, total_iters: 16789, s_err: 0.0040
# Ep: 30/100, iter: 251/572, total_iters: 16839, s_err: 0.0018
# Ep: 30/100, iter: 301/572, total_iters: 16889, s_err: 0.0057
# Ep: 30/100, iter: 351/572, total_iters: 16939, s_err: 0.0111
# Ep: 30/100, iter: 401/572, total_iters: 16989, s_err: 0.0177
# Ep: 30/100, iter: 451/572, total_iters: 17039, s_err: 0.0084
# Ep: 30/100, iter: 501/572, total_iters: 17089, s_err: 0.0034
# Ep: 30/100, iter: 551/572, total_iters: 17139, s_err: 0.0124
# Ep: 30/100, iter: 572/572, total_iters: 17160, s_err: 0.0519
# Source test acc: 89.11
# [[1469   38   43   27    2    6   74   10   32   43]
#  [  20 4856   48   32   17   18   11   62   22   13]
#  [   6   76 3863   46   13   18   14   58   27   28]
#  [   5   75   64 2432    3   68   26   11   66  132]
#  [  11  142   49   43 2137   12   32   13   32   52]
#  [   3   38   26   84    4 2104   64    7   19   35]
#  [  15   31   14   31    6   50 1751   12   53   14]
#  [   6   95   39   19    2   12    6 1821    6   13]
#  [  11   28   24   43    2   23   84    5 1383   57]
#  [  18   30   68   26    3   16   15   13   26 1380]]
# Ep: 31/100, iter: 1/572, total_iters: 17161, s_err: 0.0116
# Ep: 31/100, iter: 51/572, total_iters: 17211, s_err: 0.0261
# Ep: 31/100, iter: 101/572, total_iters: 17261, s_err: 0.0102
# Ep: 31/100, iter: 151/572, total_iters: 17311, s_err: 0.0063
# Ep: 31/100, iter: 201/572, total_iters: 17361, s_err: 0.0374
# Ep: 31/100, iter: 251/572, total_iters: 17411, s_err: 0.0550
# Ep: 31/100, iter: 301/572, total_iters: 17461, s_err: 0.0175
# Ep: 31/100, iter: 351/572, total_iters: 17511, s_err: 0.0229
# Ep: 31/100, iter: 401/572, total_iters: 17561, s_err: 0.0255
# Ep: 31/100, iter: 451/572, total_iters: 17611, s_err: 0.0021
# Ep: 31/100, iter: 501/572, total_iters: 17661, s_err: 0.0042
# Ep: 31/100, iter: 551/572, total_iters: 17711, s_err: 0.0020
# Ep: 31/100, iter: 572/572, total_iters: 17732, s_err: 0.0331
# Ep: 32/100, iter: 1/572, total_iters: 17733, s_err: 0.0098
# Ep: 32/100, iter: 51/572, total_iters: 17783, s_err: 0.0062
# Ep: 32/100, iter: 101/572, total_iters: 17833, s_err: 0.0073
# Ep: 32/100, iter: 151/572, total_iters: 17883, s_err: 0.0037
# Ep: 32/100, iter: 201/572, total_iters: 17933, s_err: 0.0061
# Ep: 32/100, iter: 251/572, total_iters: 17983, s_err: 0.0105
# Ep: 32/100, iter: 301/572, total_iters: 18033, s_err: 0.0040
# Ep: 32/100, iter: 351/572, total_iters: 18083, s_err: 0.0038
# Ep: 32/100, iter: 401/572, total_iters: 18133, s_err: 0.0062
# Ep: 32/100, iter: 451/572, total_iters: 18183, s_err: 0.0124
# Ep: 32/100, iter: 501/572, total_iters: 18233, s_err: 0.0080
# Ep: 32/100, iter: 551/572, total_iters: 18283, s_err: 0.0652
# Ep: 32/100, iter: 572/572, total_iters: 18304, s_err: 0.0211
# Ep: 33/100, iter: 1/572, total_iters: 18305, s_err: 0.0071
# Ep: 33/100, iter: 51/572, total_iters: 18355, s_err: 0.0322
# Ep: 33/100, iter: 101/572, total_iters: 18405, s_err: 0.0306
# Ep: 33/100, iter: 151/572, total_iters: 18455, s_err: 0.0074
# Ep: 33/100, iter: 201/572, total_iters: 18505, s_err: 0.0179
# Ep: 33/100, iter: 251/572, total_iters: 18555, s_err: 0.0098
# Ep: 33/100, iter: 301/572, total_iters: 18605, s_err: 0.0230
# Ep: 33/100, iter: 351/572, total_iters: 18655, s_err: 0.0216
# Ep: 33/100, iter: 401/572, total_iters: 18705, s_err: 0.0066
# Ep: 33/100, iter: 451/572, total_iters: 18755, s_err: 0.0022
# Ep: 33/100, iter: 501/572, total_iters: 18805, s_err: 0.0149
# Ep: 33/100, iter: 551/572, total_iters: 18855, s_err: 0.0290
# Ep: 33/100, iter: 572/572, total_iters: 18876, s_err: 0.0201
# Ep: 34/100, iter: 1/572, total_iters: 18877, s_err: 0.0096
# Ep: 34/100, iter: 51/572, total_iters: 18927, s_err: 0.0015
# Ep: 34/100, iter: 101/572, total_iters: 18977, s_err: 0.0110
# Ep: 34/100, iter: 151/572, total_iters: 19027, s_err: 0.0009
# Ep: 34/100, iter: 201/572, total_iters: 19077, s_err: 0.0513
# Ep: 34/100, iter: 251/572, total_iters: 19127, s_err: 0.0096
# Ep: 34/100, iter: 301/572, total_iters: 19177, s_err: 0.0032
# Ep: 34/100, iter: 351/572, total_iters: 19227, s_err: 0.0034
# Ep: 34/100, iter: 401/572, total_iters: 19277, s_err: 0.0197
# Ep: 34/100, iter: 451/572, total_iters: 19327, s_err: 0.0209
# Ep: 34/100, iter: 501/572, total_iters: 19377, s_err: 0.0129
# Ep: 34/100, iter: 551/572, total_iters: 19427, s_err: 0.0032
# Ep: 34/100, iter: 572/572, total_iters: 19448, s_err: 0.0063
# Ep: 35/100, iter: 1/572, total_iters: 19449, s_err: 0.0265
# Ep: 35/100, iter: 51/572, total_iters: 19499, s_err: 0.0030
# Ep: 35/100, iter: 101/572, total_iters: 19549, s_err: 0.0092
# Ep: 35/100, iter: 151/572, total_iters: 19599, s_err: 0.0022
# Ep: 35/100, iter: 201/572, total_iters: 19649, s_err: 0.0020
# Ep: 35/100, iter: 251/572, total_iters: 19699, s_err: 0.0037
# Ep: 35/100, iter: 301/572, total_iters: 19749, s_err: 0.0096
# Ep: 35/100, iter: 351/572, total_iters: 19799, s_err: 0.0287
# Ep: 35/100, iter: 401/572, total_iters: 19849, s_err: 0.0344
# Ep: 35/100, iter: 451/572, total_iters: 19899, s_err: 0.0039
# Ep: 35/100, iter: 501/572, total_iters: 19949, s_err: 0.0280
# Ep: 35/100, iter: 551/572, total_iters: 19999, s_err: 0.0118
# Ep: 35/100, iter: 572/572, total_iters: 20020, s_err: 0.0015
# Ep: 36/100, iter: 1/572, total_iters: 20021, s_err: 0.0018
# Ep: 36/100, iter: 51/572, total_iters: 20071, s_err: 0.0148
# Ep: 36/100, iter: 101/572, total_iters: 20121, s_err: 0.0017
# Ep: 36/100, iter: 151/572, total_iters: 20171, s_err: 0.0084
# Ep: 36/100, iter: 201/572, total_iters: 20221, s_err: 0.0140
# Ep: 36/100, iter: 251/572, total_iters: 20271, s_err: 0.0099
# Ep: 36/100, iter: 301/572, total_iters: 20321, s_err: 0.0015
# Ep: 36/100, iter: 351/572, total_iters: 20371, s_err: 0.0053
# Ep: 36/100, iter: 401/572, total_iters: 20421, s_err: 0.0062
# Ep: 36/100, iter: 451/572, total_iters: 20471, s_err: 0.0048
# Ep: 36/100, iter: 501/572, total_iters: 20521, s_err: 0.0234
# Ep: 36/100, iter: 551/572, total_iters: 20571, s_err: 0.0260
# Ep: 36/100, iter: 572/572, total_iters: 20592, s_err: 0.0063
# Ep: 37/100, iter: 1/572, total_iters: 20593, s_err: 0.0021
# Ep: 37/100, iter: 51/572, total_iters: 20643, s_err: 0.0016
# Ep: 37/100, iter: 101/572, total_iters: 20693, s_err: 0.0025
# Ep: 37/100, iter: 151/572, total_iters: 20743, s_err: 0.0011
# Ep: 37/100, iter: 201/572, total_iters: 20793, s_err: 0.0128
# Ep: 37/100, iter: 251/572, total_iters: 20843, s_err: 0.0090
# Ep: 37/100, iter: 301/572, total_iters: 20893, s_err: 0.0218
# Ep: 37/100, iter: 351/572, total_iters: 20943, s_err: 0.0194
# Ep: 37/100, iter: 401/572, total_iters: 20993, s_err: 0.0092
# Ep: 37/100, iter: 451/572, total_iters: 21043, s_err: 0.0194
# Ep: 37/100, iter: 501/572, total_iters: 21093, s_err: 0.0098
# Ep: 37/100, iter: 551/572, total_iters: 21143, s_err: 0.0280
# Ep: 37/100, iter: 572/572, total_iters: 21164, s_err: 0.0368
# Ep: 38/100, iter: 1/572, total_iters: 21165, s_err: 0.0046
# Ep: 38/100, iter: 51/572, total_iters: 21215, s_err: 0.0067
# Ep: 38/100, iter: 101/572, total_iters: 21265, s_err: 0.0018
# Ep: 38/100, iter: 151/572, total_iters: 21315, s_err: 0.0093
# Ep: 38/100, iter: 201/572, total_iters: 21365, s_err: 0.0097
# Ep: 38/100, iter: 251/572, total_iters: 21415, s_err: 0.0030
# Ep: 38/100, iter: 301/572, total_iters: 21465, s_err: 0.0055
# Ep: 38/100, iter: 351/572, total_iters: 21515, s_err: 0.0322
# Ep: 38/100, iter: 401/572, total_iters: 21565, s_err: 0.0106
# Ep: 38/100, iter: 451/572, total_iters: 21615, s_err: 0.0042
# Ep: 38/100, iter: 501/572, total_iters: 21665, s_err: 0.0251
# Ep: 38/100, iter: 551/572, total_iters: 21715, s_err: 0.0639
# Ep: 38/100, iter: 572/572, total_iters: 21736, s_err: 0.0075
# Ep: 39/100, iter: 1/572, total_iters: 21737, s_err: 0.0007
# Ep: 39/100, iter: 51/572, total_iters: 21787, s_err: 0.0023
# Ep: 39/100, iter: 101/572, total_iters: 21837, s_err: 0.0054
# Ep: 39/100, iter: 151/572, total_iters: 21887, s_err: 0.0087
# Ep: 39/100, iter: 201/572, total_iters: 21937, s_err: 0.0065
# Ep: 39/100, iter: 251/572, total_iters: 21987, s_err: 0.0043
# Ep: 39/100, iter: 301/572, total_iters: 22037, s_err: 0.0045
# Ep: 39/100, iter: 351/572, total_iters: 22087, s_err: 0.0171
# Ep: 39/100, iter: 401/572, total_iters: 22137, s_err: 0.0196
# Ep: 39/100, iter: 451/572, total_iters: 22187, s_err: 0.0078
# Ep: 39/100, iter: 501/572, total_iters: 22237, s_err: 0.0159
# Ep: 39/100, iter: 551/572, total_iters: 22287, s_err: 0.0248
# Ep: 39/100, iter: 572/572, total_iters: 22308, s_err: 0.0164
# Ep: 40/100, iter: 1/572, total_iters: 22309, s_err: 0.0175
# Ep: 40/100, iter: 51/572, total_iters: 22359, s_err: 0.0122
# Ep: 40/100, iter: 101/572, total_iters: 22409, s_err: 0.0044
# Ep: 40/100, iter: 151/572, total_iters: 22459, s_err: 0.0128
# Ep: 40/100, iter: 201/572, total_iters: 22509, s_err: 0.0178
# Ep: 40/100, iter: 251/572, total_iters: 22559, s_err: 0.0442
# Ep: 40/100, iter: 301/572, total_iters: 22609, s_err: 0.0092
# Ep: 40/100, iter: 351/572, total_iters: 22659, s_err: 0.0354
# Ep: 40/100, iter: 401/572, total_iters: 22709, s_err: 0.0030
# Ep: 40/100, iter: 451/572, total_iters: 22759, s_err: 0.0053
# Ep: 40/100, iter: 501/572, total_iters: 22809, s_err: 0.0426
# Ep: 40/100, iter: 551/572, total_iters: 22859, s_err: 0.0110
# Ep: 40/100, iter: 572/572, total_iters: 22880, s_err: 0.0627
# Source test acc: 88.20
# [[1482   37   75    3   10   13   53   14   25   32]
#  [  25 4673   94   12  109   29   14  114   23    6]
#  [   7   32 3904   24   40   23    7   73   21   18]
#  [   5   75  153 2114   41  204   18   24   81  167]
#  [   8   53   44   11 2340   17    7   15   16   12]
#  [   4   19   30   33   24 2187   41   14   15   17]
#  [  14   21   29   10   37   99 1682   21   54   10]
#  [   2   54   66    7   12   11    6 1842    7   12]
#  [  13   16   45   17   32   38   68    5 1381   45]
#  [  23   22  103   11   12   30    8   15   15 1356]]
# Ep: 41/100, iter: 1/572, total_iters: 22881, s_err: 0.0366
# Ep: 41/100, iter: 51/572, total_iters: 22931, s_err: 0.0025
# Ep: 41/100, iter: 101/572, total_iters: 22981, s_err: 0.0051
# Ep: 41/100, iter: 151/572, total_iters: 23031, s_err: 0.0009
# Ep: 41/100, iter: 201/572, total_iters: 23081, s_err: 0.0007
# Ep: 41/100, iter: 251/572, total_iters: 23131, s_err: 0.0083
# Ep: 41/100, iter: 301/572, total_iters: 23181, s_err: 0.0006
# Ep: 41/100, iter: 351/572, total_iters: 23231, s_err: 0.0116
# Ep: 41/100, iter: 401/572, total_iters: 23281, s_err: 0.0210
# Ep: 41/100, iter: 451/572, total_iters: 23331, s_err: 0.0143
# Ep: 41/100, iter: 501/572, total_iters: 23381, s_err: 0.0019
# Ep: 41/100, iter: 551/572, total_iters: 23431, s_err: 0.0444
# Ep: 41/100, iter: 572/572, total_iters: 23452, s_err: 0.0226
# Ep: 42/100, iter: 1/572, total_iters: 23453, s_err: 0.0222
# Ep: 42/100, iter: 51/572, total_iters: 23503, s_err: 0.0033
# Ep: 42/100, iter: 101/572, total_iters: 23553, s_err: 0.0083
# Ep: 42/100, iter: 151/572, total_iters: 23603, s_err: 0.0056
# Ep: 42/100, iter: 201/572, total_iters: 23653, s_err: 0.0163
# Ep: 42/100, iter: 251/572, total_iters: 23703, s_err: 0.0227
# Ep: 42/100, iter: 301/572, total_iters: 23753, s_err: 0.0118
# Ep: 42/100, iter: 351/572, total_iters: 23803, s_err: 0.0013
# Ep: 42/100, iter: 401/572, total_iters: 23853, s_err: 0.0012
# Ep: 42/100, iter: 451/572, total_iters: 23903, s_err: 0.0007
# Ep: 42/100, iter: 501/572, total_iters: 23953, s_err: 0.0032
# Ep: 42/100, iter: 551/572, total_iters: 24003, s_err: 0.0109
# Ep: 42/100, iter: 572/572, total_iters: 24024, s_err: 0.0025
# Ep: 43/100, iter: 1/572, total_iters: 24025, s_err: 0.0023
# Ep: 43/100, iter: 51/572, total_iters: 24075, s_err: 0.0123
# Ep: 43/100, iter: 101/572, total_iters: 24125, s_err: 0.0016
# Ep: 43/100, iter: 151/572, total_iters: 24175, s_err: 0.0047
# Ep: 43/100, iter: 201/572, total_iters: 24225, s_err: 0.0009
# Ep: 43/100, iter: 251/572, total_iters: 24275, s_err: 0.0008
# Ep: 43/100, iter: 301/572, total_iters: 24325, s_err: 0.0374
# Ep: 43/100, iter: 351/572, total_iters: 24375, s_err: 0.0606
# Ep: 43/100, iter: 401/572, total_iters: 24425, s_err: 0.0348
# Ep: 43/100, iter: 451/572, total_iters: 24475, s_err: 0.0871
# Ep: 43/100, iter: 501/572, total_iters: 24525, s_err: 0.0009
# Ep: 43/100, iter: 551/572, total_iters: 24575, s_err: 0.0050
# Ep: 43/100, iter: 572/572, total_iters: 24596, s_err: 0.1212
# Ep: 44/100, iter: 1/572, total_iters: 24597, s_err: 0.0016
# Ep: 44/100, iter: 51/572, total_iters: 24647, s_err: 0.0059
# Ep: 44/100, iter: 101/572, total_iters: 24697, s_err: 0.0125
# Ep: 44/100, iter: 151/572, total_iters: 24747, s_err: 0.0091
# Ep: 44/100, iter: 201/572, total_iters: 24797, s_err: 0.0579
# Ep: 44/100, iter: 251/572, total_iters: 24847, s_err: 0.0559
# Ep: 44/100, iter: 301/572, total_iters: 24897, s_err: 0.0047
# Ep: 44/100, iter: 351/572, total_iters: 24947, s_err: 0.0366
# Ep: 44/100, iter: 401/572, total_iters: 24997, s_err: 0.0044
# Ep: 44/100, iter: 451/572, total_iters: 25047, s_err: 0.0047
# Ep: 44/100, iter: 501/572, total_iters: 25097, s_err: 0.0022
# Ep: 44/100, iter: 551/572, total_iters: 25147, s_err: 0.0051
# Ep: 44/100, iter: 572/572, total_iters: 25168, s_err: 0.0085
# Ep: 45/100, iter: 1/572, total_iters: 25169, s_err: 0.0085
# Ep: 45/100, iter: 51/572, total_iters: 25219, s_err: 0.0023
# Ep: 45/100, iter: 101/572, total_iters: 25269, s_err: 0.0013
# Ep: 45/100, iter: 151/572, total_iters: 25319, s_err: 0.0008
# Ep: 45/100, iter: 201/572, total_iters: 25369, s_err: 0.0042
# Ep: 45/100, iter: 251/572, total_iters: 25419, s_err: 0.0014
# Ep: 45/100, iter: 301/572, total_iters: 25469, s_err: 0.0166
# Ep: 45/100, iter: 351/572, total_iters: 25519, s_err: 0.0243
# Ep: 45/100, iter: 401/572, total_iters: 25569, s_err: 0.0096
# Ep: 45/100, iter: 451/572, total_iters: 25619, s_err: 0.0107
# Ep: 45/100, iter: 501/572, total_iters: 25669, s_err: 0.0095
# Ep: 45/100, iter: 551/572, total_iters: 25719, s_err: 0.0029
# Ep: 45/100, iter: 572/572, total_iters: 25740, s_err: 0.0138
# Ep: 46/100, iter: 1/572, total_iters: 25741, s_err: 0.0067
# Ep: 46/100, iter: 51/572, total_iters: 25791, s_err: 0.0029
# Ep: 46/100, iter: 101/572, total_iters: 25841, s_err: 0.0019
# Ep: 46/100, iter: 151/572, total_iters: 25891, s_err: 0.0043
# Ep: 46/100, iter: 201/572, total_iters: 25941, s_err: 0.0177
# Ep: 46/100, iter: 251/572, total_iters: 25991, s_err: 0.0029
# Ep: 46/100, iter: 301/572, total_iters: 26041, s_err: 0.0010
# Ep: 46/100, iter: 351/572, total_iters: 26091, s_err: 0.0010
# Ep: 46/100, iter: 401/572, total_iters: 26141, s_err: 0.0140
# Ep: 46/100, iter: 451/572, total_iters: 26191, s_err: 0.0014
# Ep: 46/100, iter: 501/572, total_iters: 26241, s_err: 0.0027
# Ep: 46/100, iter: 551/572, total_iters: 26291, s_err: 0.0008
# Ep: 46/100, iter: 572/572, total_iters: 26312, s_err: 0.0091
# Ep: 47/100, iter: 1/572, total_iters: 26313, s_err: 0.0044
# Ep: 47/100, iter: 51/572, total_iters: 26363, s_err: 0.0099
# Ep: 47/100, iter: 101/572, total_iters: 26413, s_err: 0.0165
# Ep: 47/100, iter: 151/572, total_iters: 26463, s_err: 0.0027
# Ep: 47/100, iter: 201/572, total_iters: 26513, s_err: 0.0002
# Ep: 47/100, iter: 251/572, total_iters: 26563, s_err: 0.0006
# Ep: 47/100, iter: 301/572, total_iters: 26613, s_err: 0.0220
# Ep: 47/100, iter: 351/572, total_iters: 26663, s_err: 0.0102
# Ep: 47/100, iter: 401/572, total_iters: 26713, s_err: 0.0040
# Ep: 47/100, iter: 451/572, total_iters: 26763, s_err: 0.0201
# Ep: 47/100, iter: 501/572, total_iters: 26813, s_err: 0.0038
# Ep: 47/100, iter: 551/572, total_iters: 26863, s_err: 0.0563
# Ep: 47/100, iter: 572/572, total_iters: 26884, s_err: 0.0111
# Ep: 48/100, iter: 1/572, total_iters: 26885, s_err: 0.0188
# Ep: 48/100, iter: 51/572, total_iters: 26935, s_err: 0.0098
# Ep: 48/100, iter: 101/572, total_iters: 26985, s_err: 0.0033
# Ep: 48/100, iter: 151/572, total_iters: 27035, s_err: 0.0026
# Ep: 48/100, iter: 201/572, total_iters: 27085, s_err: 0.0013
# Ep: 48/100, iter: 251/572, total_iters: 27135, s_err: 0.0039
# Ep: 48/100, iter: 301/572, total_iters: 27185, s_err: 0.0023
# Ep: 48/100, iter: 351/572, total_iters: 27235, s_err: 0.0014
# Ep: 48/100, iter: 401/572, total_iters: 27285, s_err: 0.0467
# Ep: 48/100, iter: 451/572, total_iters: 27335, s_err: 0.0581
# Ep: 48/100, iter: 501/572, total_iters: 27385, s_err: 0.0490
# Ep: 48/100, iter: 551/572, total_iters: 27435, s_err: 0.0149
# Ep: 48/100, iter: 572/572, total_iters: 27456, s_err: 0.0305
# Ep: 49/100, iter: 1/572, total_iters: 27457, s_err: 0.0240
# Ep: 49/100, iter: 51/572, total_iters: 27507, s_err: 0.0303
# Ep: 49/100, iter: 101/572, total_iters: 27557, s_err: 0.0366
# Ep: 49/100, iter: 151/572, total_iters: 27607, s_err: 0.0059
# Ep: 49/100, iter: 201/572, total_iters: 27657, s_err: 0.0140
# Ep: 49/100, iter: 251/572, total_iters: 27707, s_err: 0.0057
# Ep: 49/100, iter: 301/572, total_iters: 27757, s_err: 0.0009
# Ep: 49/100, iter: 351/572, total_iters: 27807, s_err: 0.0005
# Ep: 49/100, iter: 401/572, total_iters: 27857, s_err: 0.0080
# Ep: 49/100, iter: 451/572, total_iters: 27907, s_err: 0.0737
# Ep: 49/100, iter: 501/572, total_iters: 27957, s_err: 0.0116
# Ep: 49/100, iter: 551/572, total_iters: 28007, s_err: 0.0023
# Ep: 49/100, iter: 572/572, total_iters: 28028, s_err: 0.0227
# Ep: 50/100, iter: 1/572, total_iters: 28029, s_err: 0.0018
# Ep: 50/100, iter: 51/572, total_iters: 28079, s_err: 0.0472
# Ep: 50/100, iter: 101/572, total_iters: 28129, s_err: 0.0072
# Ep: 50/100, iter: 151/572, total_iters: 28179, s_err: 0.0065
# Ep: 50/100, iter: 201/572, total_iters: 28229, s_err: 0.0157
# Ep: 50/100, iter: 251/572, total_iters: 28279, s_err: 0.0011
# Ep: 50/100, iter: 301/572, total_iters: 28329, s_err: 0.0055
# Ep: 50/100, iter: 351/572, total_iters: 28379, s_err: 0.0299
# Ep: 50/100, iter: 401/572, total_iters: 28429, s_err: 0.0286
# Ep: 50/100, iter: 451/572, total_iters: 28479, s_err: 0.0070
# Ep: 50/100, iter: 501/572, total_iters: 28529, s_err: 0.0138
# Ep: 50/100, iter: 551/572, total_iters: 28579, s_err: 0.0142
# Ep: 50/100, iter: 572/572, total_iters: 28600, s_err: 0.0740
# Source test acc: 89.84
# [[1481   32   22   32   10    5   65   11   38   48]
#  [  20 4768   43   39   77   14   13   77   34   14]
#  [   5   42 3871   82   33   15   14   41   28   18]
#  [   6   45   57 2412   20   69   20   17  101  135]
#  [  12   55   40   27 2305    6   19    7   25   27]
#  [   6   17   23   60   13 2122   75   10   34   24]
#  [  17   19   11   19   16   29 1749    9   90   18]
#  [   4   71   48   26    6    8   10 1818    9   19]
#  [   8   14   19   30   12   12   65    3 1462   35]
#  [  17   16   62   23    8   23   11    6   29 1400]]
# Ep: 51/100, iter: 1/572, total_iters: 28601, s_err: 0.0024
# Ep: 51/100, iter: 51/572, total_iters: 28651, s_err: 0.0016
# Ep: 51/100, iter: 101/572, total_iters: 28701, s_err: 0.0056
# Ep: 51/100, iter: 151/572, total_iters: 28751, s_err: 0.0015
# Ep: 51/100, iter: 201/572, total_iters: 28801, s_err: 0.0022
# Ep: 51/100, iter: 251/572, total_iters: 28851, s_err: 0.0035
# Ep: 51/100, iter: 301/572, total_iters: 28901, s_err: 0.0022
# Ep: 51/100, iter: 351/572, total_iters: 28951, s_err: 0.0013
# Ep: 51/100, iter: 401/572, total_iters: 29001, s_err: 0.0041
# Ep: 51/100, iter: 451/572, total_iters: 29051, s_err: 0.0019
# Ep: 51/100, iter: 501/572, total_iters: 29101, s_err: 0.0012
# Ep: 51/100, iter: 551/572, total_iters: 29151, s_err: 0.0019
# Ep: 51/100, iter: 572/572, total_iters: 29172, s_err: 0.0117
# Ep: 52/100, iter: 1/572, total_iters: 29173, s_err: 0.0046
# Ep: 52/100, iter: 51/572, total_iters: 29223, s_err: 0.0013
# Ep: 52/100, iter: 101/572, total_iters: 29273, s_err: 0.0038
# Ep: 52/100, iter: 151/572, total_iters: 29323, s_err: 0.0101
# Ep: 52/100, iter: 201/572, total_iters: 29373, s_err: 0.0107
# Ep: 52/100, iter: 251/572, total_iters: 29423, s_err: 0.0095
# Ep: 52/100, iter: 301/572, total_iters: 29473, s_err: 0.0003
# Ep: 52/100, iter: 351/572, total_iters: 29523, s_err: 0.0057
# Ep: 52/100, iter: 401/572, total_iters: 29573, s_err: 0.0152
# Ep: 52/100, iter: 451/572, total_iters: 29623, s_err: 0.0041
# Ep: 52/100, iter: 501/572, total_iters: 29673, s_err: 0.0015
# Ep: 52/100, iter: 551/572, total_iters: 29723, s_err: 0.0096
# Ep: 52/100, iter: 572/572, total_iters: 29744, s_err: 0.0056
# Ep: 53/100, iter: 1/572, total_iters: 29745, s_err: 0.0006
# Ep: 53/100, iter: 51/572, total_iters: 29795, s_err: 0.0002
# Ep: 53/100, iter: 101/572, total_iters: 29845, s_err: 0.0003
# Ep: 53/100, iter: 151/572, total_iters: 29895, s_err: 0.0024
# Ep: 53/100, iter: 201/572, total_iters: 29945, s_err: 0.0015
# Ep: 53/100, iter: 251/572, total_iters: 29995, s_err: 0.0024
# Ep: 53/100, iter: 301/572, total_iters: 30045, s_err: 0.0039
# Ep: 53/100, iter: 351/572, total_iters: 30095, s_err: 0.0092
# Ep: 53/100, iter: 401/572, total_iters: 30145, s_err: 0.0018
# Ep: 53/100, iter: 451/572, total_iters: 30195, s_err: 0.0120
# Ep: 53/100, iter: 501/572, total_iters: 30245, s_err: 0.0008
# Ep: 53/100, iter: 551/572, total_iters: 30295, s_err: 0.0013
# Ep: 53/100, iter: 572/572, total_iters: 30316, s_err: 0.0035
# Ep: 54/100, iter: 1/572, total_iters: 30317, s_err: 0.0043
# Ep: 54/100, iter: 51/572, total_iters: 30367, s_err: 0.0020
# Ep: 54/100, iter: 101/572, total_iters: 30417, s_err: 0.0091
# Ep: 54/100, iter: 151/572, total_iters: 30467, s_err: 0.0078
# Ep: 54/100, iter: 201/572, total_iters: 30517, s_err: 0.0001
# Ep: 54/100, iter: 251/572, total_iters: 30567, s_err: 0.0003
# Ep: 54/100, iter: 301/572, total_iters: 30617, s_err: 0.0013
# Ep: 54/100, iter: 351/572, total_iters: 30667, s_err: 0.0037
# Ep: 54/100, iter: 401/572, total_iters: 30717, s_err: 0.0008
# Ep: 54/100, iter: 451/572, total_iters: 30767, s_err: 0.0033
# Ep: 54/100, iter: 501/572, total_iters: 30817, s_err: 0.0062
# Ep: 54/100, iter: 551/572, total_iters: 30867, s_err: 0.0538
# Ep: 54/100, iter: 572/572, total_iters: 30888, s_err: 0.0063
# Ep: 55/100, iter: 1/572, total_iters: 30889, s_err: 0.0052
# Ep: 55/100, iter: 51/572, total_iters: 30939, s_err: 0.0197
# Ep: 55/100, iter: 101/572, total_iters: 30989, s_err: 0.0013
# Ep: 55/100, iter: 151/572, total_iters: 31039, s_err: 0.0114
# Ep: 55/100, iter: 201/572, total_iters: 31089, s_err: 0.0045
# Ep: 55/100, iter: 251/572, total_iters: 31139, s_err: 0.0005
# Ep: 55/100, iter: 301/572, total_iters: 31189, s_err: 0.0003
# Ep: 55/100, iter: 351/572, total_iters: 31239, s_err: 0.0001
# Ep: 55/100, iter: 401/572, total_iters: 31289, s_err: 0.0042
# Ep: 55/100, iter: 451/572, total_iters: 31339, s_err: 0.0033
# Ep: 55/100, iter: 501/572, total_iters: 31389, s_err: 0.0002
# Ep: 55/100, iter: 551/572, total_iters: 31439, s_err: 0.0020
# Ep: 55/100, iter: 572/572, total_iters: 31460, s_err: 0.0367
# ...
# Ep: 85/100, iter: 51/572, total_iters: 48099, s_err: 0.0236
# Ep: 85/100, iter: 101/572, total_iters: 48149, s_err: 0.0013
# Ep: 85/100, iter: 151/572, total_iters: 48199, s_err: 0.0012
# Ep: 85/100, iter: 201/572, total_iters: 48249, s_err: 0.0016
# Ep: 85/100, iter: 251/572, total_iters: 48299, s_err: 0.0005
# Ep: 85/100, iter: 301/572, total_iters: 48349, s_err: 0.0032
# Ep: 85/100, iter: 351/572, total_iters: 48399, s_err: 0.0059
# Ep: 85/100, iter: 401/572, total_iters: 48449, s_err: 0.0006
# Ep: 85/100, iter: 451/572, total_iters: 48499, s_err: 0.1463
# Ep: 85/100, iter: 501/572, total_iters: 48549, s_err: 0.0035
# Ep: 85/100, iter: 551/572, total_iters: 48599, s_err: 0.0083
# Ep: 85/100, iter: 572/572, total_iters: 48620, s_err: 0.0015
# Ep: 86/100, iter: 1/572, total_iters: 48621, s_err: 0.0001
# Ep: 86/100, iter: 51/572, total_iters: 48671, s_err: 0.0013
# Ep: 86/100, iter: 101/572, total_iters: 48721, s_err: 0.0026
# Ep: 86/100, iter: 151/572, total_iters: 48771, s_err: 0.0018
# Ep: 86/100, iter: 201/572, total_iters: 48821, s_err: 0.0008
# Ep: 86/100, iter: 251/572, total_iters: 48871, s_err: 0.0007
# Ep: 86/100, iter: 301/572, total_iters: 48921, s_err: 0.0083
# Ep: 86/100, iter: 351/572, total_iters: 48971, s_err: 0.0006
# Ep: 86/100, iter: 401/572, total_iters: 49021, s_err: 0.0002
# Ep: 86/100, iter: 451/572, total_iters: 49071, s_err: 0.0001
# Ep: 86/100, iter: 501/572, total_iters: 49121, s_err: 0.0030
# Ep: 86/100, iter: 551/572, total_iters: 49171, s_err: 0.0011
# Ep: 86/100, iter: 572/572, total_iters: 49192, s_err: 0.0010
# Ep: 87/100, iter: 1/572, total_iters: 49193, s_err: 0.0031
# Ep: 87/100, iter: 51/572, total_iters: 49243, s_err: 0.0001
# Ep: 87/100, iter: 101/572, total_iters: 49293, s_err: 0.0011
# Ep: 87/100, iter: 151/572, total_iters: 49343, s_err: 0.0004
# Ep: 87/100, iter: 201/572, total_iters: 49393, s_err: 0.0002
# Ep: 87/100, iter: 251/572, total_iters: 49443, s_err: 0.0001
# Ep: 87/100, iter: 301/572, total_iters: 49493, s_err: 0.0002
# Ep: 87/100, iter: 351/572, total_iters: 49543, s_err: 0.0025
# Ep: 87/100, iter: 401/572, total_iters: 49593, s_err: 0.0005
# Ep: 87/100, iter: 451/572, total_iters: 49643, s_err: 0.0010
# Ep: 87/100, iter: 501/572, total_iters: 49693, s_err: 0.0044
# Ep: 87/100, iter: 551/572, total_iters: 49743, s_err: 0.0002
# Ep: 87/100, iter: 572/572, total_iters: 49764, s_err: 0.0063
# Ep: 88/100, iter: 1/572, total_iters: 49765, s_err: 0.0038
# Ep: 88/100, iter: 51/572, total_iters: 49815, s_err: 0.0001
# Ep: 88/100, iter: 101/572, total_iters: 49865, s_err: 0.0153
# Ep: 88/100, iter: 151/572, total_iters: 49915, s_err: 0.0035
# Ep: 88/100, iter: 201/572, total_iters: 49965, s_err: 0.0016
# Ep: 88/100, iter: 251/572, total_iters: 50015, s_err: 0.0259
# Ep: 88/100, iter: 301/572, total_iters: 50065, s_err: 0.0093
# Ep: 88/100, iter: 351/572, total_iters: 50115, s_err: 0.0002
# Ep: 88/100, iter: 401/572, total_iters: 50165, s_err: 0.0094
# Ep: 88/100, iter: 451/572, total_iters: 50215, s_err: 0.0007
# Ep: 88/100, iter: 501/572, total_iters: 50265, s_err: 0.0014
# Ep: 88/100, iter: 551/572, total_iters: 50315, s_err: 0.0521
# Ep: 88/100, iter: 572/572, total_iters: 50336, s_err: 0.0009
# Ep: 89/100, iter: 1/572, total_iters: 50337, s_err: 0.0098
# Ep: 89/100, iter: 51/572, total_iters: 50387, s_err: 0.0245
# Ep: 89/100, iter: 101/572, total_iters: 50437, s_err: 0.0352
# Ep: 89/100, iter: 151/572, total_iters: 50487, s_err: 0.0010
# Ep: 89/100, iter: 201/572, total_iters: 50537, s_err: 0.0003
# Ep: 89/100, iter: 251/572, total_iters: 50587, s_err: 0.0005
# Ep: 89/100, iter: 301/572, total_iters: 50637, s_err: 0.0044
# Ep: 89/100, iter: 351/572, total_iters: 50687, s_err: 0.0031
# Ep: 89/100, iter: 401/572, total_iters: 50737, s_err: 0.0350
# Ep: 89/100, iter: 451/572, total_iters: 50787, s_err: 0.0011
# Ep: 89/100, iter: 501/572, total_iters: 50837, s_err: 0.0024
# Ep: 89/100, iter: 551/572, total_iters: 50887, s_err: 0.0262
# Ep: 89/100, iter: 572/572, total_iters: 50908, s_err: 0.0005
# Ep: 90/100, iter: 1/572, total_iters: 50909, s_err: 0.0007
# Ep: 90/100, iter: 51/572, total_iters: 50959, s_err: 0.0310
# Ep: 90/100, iter: 101/572, total_iters: 51009, s_err: 0.0071
# Ep: 90/100, iter: 151/572, total_iters: 51059, s_err: 0.0194
# Ep: 90/100, iter: 201/572, total_iters: 51109, s_err: 0.0000
# Ep: 90/100, iter: 251/572, total_iters: 51159, s_err: 0.0005
# Ep: 90/100, iter: 301/572, total_iters: 51209, s_err: 0.0768
# Ep: 90/100, iter: 351/572, total_iters: 51259, s_err: 0.0003
# Ep: 90/100, iter: 401/572, total_iters: 51309, s_err: 0.0241
# Ep: 90/100, iter: 451/572, total_iters: 51359, s_err: 0.0392
# Ep: 90/100, iter: 501/572, total_iters: 51409, s_err: 0.0020
# Ep: 90/100, iter: 551/572, total_iters: 51459, s_err: 0.0018
# Ep: 90/100, iter: 572/572, total_iters: 51480, s_err: 0.0014
# Source test acc: 90.24
# [[1490   47   28   24   14   12   37   20   19   53]
#  [   8 4868   39   32   46   16    6   71    6    7]
#  [   6   65 3813   90   34   16   12   75   11   27]
#  [   5   68   41 2517   19   58   10   14   30  120]
#  [   7   90   28   35 2313   10   14    5    4   17]
#  [   3   19   22   88    9 2167   27   10   13   26]
#  [  16   25   11   38   32   79 1705    8   50   13]
#  [   2   86   34   27   12    5    3 1829    3   18]
#  [  12   21   19   61   21   32   64    4 1356   70]
#  [  16   17   41   26   10   26    6   11    9 1433]]
# Ep: 91/100, iter: 1/572, total_iters: 51481, s_err: 0.0018
# Ep: 91/100, iter: 51/572, total_iters: 51531, s_err: 0.0002
# Ep: 91/100, iter: 101/572, total_iters: 51581, s_err: 0.0021
# Ep: 91/100, iter: 151/572, total_iters: 51631, s_err: 0.0013
# Ep: 91/100, iter: 201/572, total_iters: 51681, s_err: 0.0011
# Ep: 91/100, iter: 251/572, total_iters: 51731, s_err: 0.0001
# Ep: 91/100, iter: 301/572, total_iters: 51781, s_err: 0.0028
# Ep: 91/100, iter: 351/572, total_iters: 51831, s_err: 0.0003
# Ep: 91/100, iter: 401/572, total_iters: 51881, s_err: 0.0056
# Ep: 91/100, iter: 451/572, total_iters: 51931, s_err: 0.0026
# Ep: 91/100, iter: 501/572, total_iters: 51981, s_err: 0.0003
# Ep: 91/100, iter: 551/572, total_iters: 52031, s_err: 0.0004
# Ep: 91/100, iter: 572/572, total_iters: 52052, s_err: 0.0019
# Ep: 92/100, iter: 1/572, total_iters: 52053, s_err: 0.0024
# Ep: 92/100, iter: 51/572, total_iters: 52103, s_err: 0.0001
# Ep: 92/100, iter: 101/572, total_iters: 52153, s_err: 0.0000
# Ep: 92/100, iter: 151/572, total_iters: 52203, s_err: 0.0004
# Ep: 92/100, iter: 201/572, total_iters: 52253, s_err: 0.0026
# Ep: 92/100, iter: 251/572, total_iters: 52303, s_err: 0.0000
# Ep: 92/100, iter: 301/572, total_iters: 52353, s_err: 0.0278
# Ep: 92/100, iter: 351/572, total_iters: 52403, s_err: 0.0011
# Ep: 92/100, iter: 401/572, total_iters: 52453, s_err: 0.0002
# Ep: 92/100, iter: 451/572, total_iters: 52503, s_err: 0.0004
# Ep: 92/100, iter: 501/572, total_iters: 52553, s_err: 0.0258
# Ep: 92/100, iter: 551/572, total_iters: 52603, s_err: 0.0212
# Ep: 92/100, iter: 572/572, total_iters: 52624, s_err: 0.0000
# Ep: 93/100, iter: 1/572, total_iters: 52625, s_err: 0.0044
# Ep: 93/100, iter: 51/572, total_iters: 52675, s_err: 0.0016
# Ep: 93/100, iter: 101/572, total_iters: 52725, s_err: 0.0002
# Ep: 93/100, iter: 151/572, total_iters: 52775, s_err: 0.0012
# Ep: 93/100, iter: 201/572, total_iters: 52825, s_err: 0.0009
# Ep: 93/100, iter: 251/572, total_iters: 52875, s_err: 0.0002
# Ep: 93/100, iter: 301/572, total_iters: 52925, s_err: 0.0122
# Ep: 93/100, iter: 351/572, total_iters: 52975, s_err: 0.0002
# Ep: 93/100, iter: 401/572, total_iters: 53025, s_err: 0.0032
# Ep: 93/100, iter: 451/572, total_iters: 53075, s_err: 0.0021
# Ep: 93/100, iter: 501/572, total_iters: 53125, s_err: 0.0080
# Ep: 93/100, iter: 551/572, total_iters: 53175, s_err: 0.0033
# Ep: 93/100, iter: 572/572, total_iters: 53196, s_err: 0.0021
# Ep: 94/100, iter: 1/572, total_iters: 53197, s_err: 0.0005
# Ep: 94/100, iter: 51/572, total_iters: 53247, s_err: 0.0092
# Ep: 94/100, iter: 101/572, total_iters: 53297, s_err: 0.0068
# Ep: 94/100, iter: 151/572, total_iters: 53347, s_err: 0.0002
# Ep: 94/100, iter: 201/572, total_iters: 53397, s_err: 0.0256
# Ep: 94/100, iter: 251/572, total_iters: 53447, s_err: 0.0004
# Ep: 94/100, iter: 301/572, total_iters: 53497, s_err: 0.0214
# Ep: 94/100, iter: 351/572, total_iters: 53547, s_err: 0.0000
# Ep: 94/100, iter: 401/572, total_iters: 53597, s_err: 0.0425
# Ep: 94/100, iter: 451/572, total_iters: 53647, s_err: 0.0041
# Ep: 94/100, iter: 501/572, total_iters: 53697, s_err: 0.0008
# Ep: 94/100, iter: 551/572, total_iters: 53747, s_err: 0.0017
# Ep: 94/100, iter: 572/572, total_iters: 53768, s_err: 0.0303
# Ep: 95/100, iter: 1/572, total_iters: 53769, s_err: 0.0334
# Ep: 95/100, iter: 51/572, total_iters: 53819, s_err: 0.0007
# Ep: 95/100, iter: 101/572, total_iters: 53869, s_err: 0.0018
# Ep: 95/100, iter: 151/572, total_iters: 53919, s_err: 0.0003
# Ep: 95/100, iter: 201/572, total_iters: 53969, s_err: 0.0006
# Ep: 95/100, iter: 251/572, total_iters: 54019, s_err: 0.0005
# Ep: 95/100, iter: 301/572, total_iters: 54069, s_err: 0.0000
# Ep: 95/100, iter: 351/572, total_iters: 54119, s_err: 0.0006
# Ep: 95/100, iter: 401/572, total_iters: 54169, s_err: 0.0265
# Ep: 95/100, iter: 451/572, total_iters: 54219, s_err: 0.0044
# Ep: 95/100, iter: 501/572, total_iters: 54269, s_err: 0.0020
# Ep: 95/100, iter: 551/572, total_iters: 54319, s_err: 0.0063
# Ep: 95/100, iter: 572/572, total_iters: 54340, s_err: 0.0146
# Ep: 96/100, iter: 1/572, total_iters: 54341, s_err: 0.0006
# Ep: 96/100, iter: 51/572, total_iters: 54391, s_err: 0.0013
# Ep: 96/100, iter: 101/572, total_iters: 54441, s_err: 0.0008
# Ep: 96/100, iter: 151/572, total_iters: 54491, s_err: 0.0003
# Ep: 96/100, iter: 201/572, total_iters: 54541, s_err: 0.0006
# Ep: 96/100, iter: 251/572, total_iters: 54591, s_err: 0.0051
# Ep: 96/100, iter: 301/572, total_iters: 54641, s_err: 0.0011
# Ep: 96/100, iter: 351/572, total_iters: 54691, s_err: 0.0013
# Ep: 96/100, iter: 401/572, total_iters: 54741, s_err: 0.0104
# Ep: 96/100, iter: 451/572, total_iters: 54791, s_err: 0.0051
# Ep: 96/100, iter: 501/572, total_iters: 54841, s_err: 0.0007
# Ep: 96/100, iter: 551/572, total_iters: 54891, s_err: 0.0023
# Ep: 96/100, iter: 572/572, total_iters: 54912, s_err: 0.0030
# Ep: 97/100, iter: 1/572, total_iters: 54913, s_err: 0.0003
# Ep: 97/100, iter: 51/572, total_iters: 54963, s_err: 0.0001
# Ep: 97/100, iter: 101/572, total_iters: 55013, s_err: 0.0001
# Ep: 97/100, iter: 151/572, total_iters: 55063, s_err: 0.0001
# Ep: 97/100, iter: 201/572, total_iters: 55113, s_err: 0.0008
# Ep: 97/100, iter: 251/572, total_iters: 55163, s_err: 0.0001
# Ep: 97/100, iter: 301/572, total_iters: 55213, s_err: 0.0009
# Ep: 97/100, iter: 351/572, total_iters: 55263, s_err: 0.0005
# Ep: 97/100, iter: 401/572, total_iters: 55313, s_err: 0.0069
# Ep: 97/100, iter: 451/572, total_iters: 55363, s_err: 0.0640
# Ep: 97/100, iter: 501/572, total_iters: 55413, s_err: 0.0019
# Ep: 97/100, iter: 551/572, total_iters: 55463, s_err: 0.0115
# Ep: 97/100, iter: 572/572, total_iters: 55484, s_err: 0.0020
# Ep: 98/100, iter: 1/572, total_iters: 55485, s_err: 0.0014
# Ep: 98/100, iter: 51/572, total_iters: 55535, s_err: 0.0003
# Ep: 98/100, iter: 101/572, total_iters: 55585, s_err: 0.0040
# Ep: 98/100, iter: 151/572, total_iters: 55635, s_err: 0.0025
# Ep: 98/100, iter: 201/572, total_iters: 55685, s_err: 0.0299
# Ep: 98/100, iter: 251/572, total_iters: 55735, s_err: 0.0023
# Ep: 98/100, iter: 301/572, total_iters: 55785, s_err: 0.0032
# Ep: 98/100, iter: 351/572, total_iters: 55835, s_err: 0.0002
# Ep: 98/100, iter: 401/572, total_iters: 55885, s_err: 0.0108
# Ep: 98/100, iter: 451/572, total_iters: 55935, s_err: 0.0001
# Ep: 98/100, iter: 501/572, total_iters: 55985, s_err: 0.0004
# Ep: 98/100, iter: 551/572, total_iters: 56035, s_err: 0.0001
# Ep: 98/100, iter: 572/572, total_iters: 56056, s_err: 0.0085
# Ep: 99/100, iter: 1/572, total_iters: 56057, s_err: 0.0015
# Ep: 99/100, iter: 51/572, total_iters: 56107, s_err: 0.0000
# Ep: 99/100, iter: 101/572, total_iters: 56157, s_err: 0.0003
# Ep: 99/100, iter: 151/572, total_iters: 56207, s_err: 0.0006
# Ep: 99/100, iter: 201/572, total_iters: 56257, s_err: 0.0001
# Ep: 99/100, iter: 251/572, total_iters: 56307, s_err: 0.0015
# Ep: 99/100, iter: 301/572, total_iters: 56357, s_err: 0.0050
# Ep: 99/100, iter: 351/572, total_iters: 56407, s_err: 0.0023
# Ep: 99/100, iter: 401/572, total_iters: 56457, s_err: 0.0001
# Ep: 99/100, iter: 451/572, total_iters: 56507, s_err: 0.0303
# Ep: 99/100, iter: 501/572, total_iters: 56557, s_err: 0.0159
# Ep: 99/100, iter: 551/572, total_iters: 56607, s_err: 0.0001
# Ep: 99/100, iter: 572/572, total_iters: 56628, s_err: 0.0004
# Ep: 100/100, iter: 1/572, total_iters: 56629, s_err: 0.0282
# Ep: 100/100, iter: 51/572, total_iters: 56679, s_err: 0.0096
# Ep: 100/100, iter: 101/572, total_iters: 56729, s_err: 0.0008
# Ep: 100/100, iter: 151/572, total_iters: 56779, s_err: 0.0378
# Ep: 100/100, iter: 201/572, total_iters: 56829, s_err: 0.0002
# Ep: 100/100, iter: 251/572, total_iters: 56879, s_err: 0.0002
# Ep: 100/100, iter: 301/572, total_iters: 56929, s_err: 0.0029
# Ep: 100/100, iter: 351/572, total_iters: 56979, s_err: 0.0003
# Ep: 100/100, iter: 401/572, total_iters: 57029, s_err: 0.0061
# Ep: 100/100, iter: 451/572, total_iters: 57079, s_err: 0.0965
# Ep: 100/100, iter: 501/572, total_iters: 57129, s_err: 0.0289
# Ep: 100/100, iter: 551/572, total_iters: 57179, s_err: 0.0001
# Ep: 100/100, iter: 572/572, total_iters: 57200, s_err: 0.0006
# Source test acc: 90.13
# [[1511   34   15   37    7    5   34   15   55   31]
#  [  16 4792   34   55   48   18    9   88   32    7]
#  [   2   53 3758  152   30   20   14   47   43   30]
#  [   4   51   27 2592   12   51    9    9   54   73]
#  [   6   66   22   38 2299   12   16   13   32   19]
#  [   2   19   14  128    7 2137   28    7   21   21]
#  [  19   17    5   41   21   73 1701    5   86    9]
#  [   2   75   32   48    6    9    4 1815    9   19]
#  [   9   12    8   55   10   30   44    4 1460   28]
#  [  27   22   30   44    4   24    7   10   29 1398]]
# Source Tr Acc: 99.76
# [[ 4895    18     5     8     0     5     4     4     1     4]
#  [    0 13851     0     0     0     1     0     0     0     0]
#  [    0     2 10570     3     1     0     0     4     0     1]
#  [    0     3     4  8479     1     1     0     3     0     1]
#  [    0     8     1     3  7439     0     0     1     0     1]
#  [    0     2     1     9     0  6867     1     0     0     0]
#  [    0     5     0     6     0    16  5691     2     1     0]
#  [    0     7     0     1     0     0     0  5585     0     0]
#  [    0    10     3     5     1     4     4     0  5014     3]
#  [    0     3     3     0     0     0     0     1     0  4649]]
# Source Te Acc: 90.24
# [[1490   47   28   24   14   12   37   20   19   53]
#  [   8 4868   39   32   46   16    6   71    6    7]
#  [   6   65 3813   90   34   16   12   75   11   27]
#  [   5   68   41 2517   19   58   10   14   30  120]
#  [   7   90   28   35 2313   10   14    5    4   17]
#  [   3   19   22   88    9 2167   27   10   13   26]
#  [  16   25   11   38   32   79 1705    8   50   13]
#  [   2   86   34   27   12    5    3 1829    3   18]
#  [  12   21   19   61   21   32   64    4 1356   70]
#  [  16   17   41   26   10   26    6   11    9 1433]]
# Target Tr Acc: 58.66
# [[2914  300  494  292  961   11  414    1  461   65]
#  [   1 3743   11   13 2883    8    2   60    1    5]
#  [  14   40 2546 2201  685  110    0  236   49   68]
#  [   0    7   39 5633   84  141    0   15   34  165]
#  [   4  128  170  147 4579   34    6   32   14  722]
#  [   0   14   17  405  518 4175   36    2   18  227]
#  [ 370   50  327   40 2668   43 2183   63  113   51]
#  [   7  243  358  486  319  145    4 4022    2  670]
#  [   2   69  195 1347  836  141  121   78 2535  515]
#  [   7  154  473  187 1533  272    9  479   20 2812]]
# Target Te Acc: 61.09
# [[523  29 112  45 134   1  58   0  71   7]
#  [  0 668   1   5 454   1   0   5   0   1]
#  [  3   4 481 379  81  14   0  50   9  11]
#  [  0   2  11 933   8  25   0   2   4  25]
#  [  0  22  27  22 784   7   1   1   1 117]
#  [  0   1   2  65  65 717   9   0   2  31]
#  [ 78  11  75   8 386  14 324  16  25  21]
#  [  1  33  75  81  55  20   1 674   0  88]
#  [  0  10  26 237  99  15  17  17 460  93]
#  [  1  28  74  33 219  38   0  69   2 545]]
# Ended at: 2025-12-04 20:10:42
# Duration: 0:34:13.235328

# %%
# ----------------------------------------
# ✨ AFTER main(args)
# ----------------------------------------

from torchvision import datasets, transforms

# Load MNIST test images
transform = transforms.Compose([
    transforms.ToTensor(),
])

mnist_test = datasets.MNIST('./data/', train=False, transform=transform, download=True)
loader = torch.utils.data.DataLoader(mnist_test, batch_size=16, shuffle=True)

# Fetch a batch
imgs, labels = next(iter(loader))
imgs = imgs.to('cuda' if torch.cuda.is_available() else 'cpu')

# Run prediction
pred = Solver.predict(imgs)

print("Ground truth labels:", labels[:10])
print("Predictions:", pred[:10])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1247963005.py in <cell line: 0>()
#      18
#      19 # Run prediction
# ---> 20 pred = Solver.predict(imgs)
#      21
#      22 print("Ground truth labels:", labels[:10])
#
# AttributeError: type object 'Solver' has no attribute 'predict'

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,2))
for i in range(8):
    plt.subplot(1,8,i+1)
    plt.imshow(imgs[i].cpu().squeeze(), cmap="gray")
    plt.title(f"P={pred[i].item()}")
    plt.axis("off")
plt.show()
